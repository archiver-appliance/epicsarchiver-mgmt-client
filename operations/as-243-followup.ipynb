# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    filename="logs/mgmt_operations.as_243_followup.log",
    encoding="utf-8",
)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
from epicsarchiver.mgmt.archiver_mgmt_info import ArchivingStatus
from epicsarchiver.mgmt.archiver_mgmt_operations import Storage
from epicsarchiver import ArchiverAppliance
from concurrent.futures import ThreadPoolExecutor

# %%
import csv

# %%
failed_pvs_filename = "AS-243-followup/failedpvs.csv"

failed_pvs = csv.reader(open(failed_pvs_filename))

failed_pvs_reader = failed_pvs
failed_pvs = []
for row in failed_pvs_reader:
    to_pv = row[0].strip()
    from_pv = row[1].strip()
    failed_pvs.append((to_pv, from_pv))

# %%
failed_pvs
# Out:
# [('HBL-010Crm:SC-FSM-700:ON', 'HBL-010Crm:SC-FSM-700:Opened'),
#  ('HBL-010Crm:SC-FSM-701:OpMode_Forced',
#   'HBL-010Crm:SC-FSM-700:OpMode_Manual'),
#  ('HBL-010Crm:SC-FSM-702:ON', 'HBL-010Crm:SC-FSM-702:Opened'),
#  ('HBL-010CDL:SC-PID-82303:MAN_SP', 'HBL-010CDL:Cryo-PID-82303:MAN_SP'),
#  ('HBL-010CDL:SC-PID-82303:ProcValueName',
#   'HBL-010CDL:Cryo-PID-82303:ProcValueName'),
#  ('HBL-010CDL:SC-PID-82304:MAN_SP', 'HBL-010CDL:Cryo-PID-82304:MAN_SP'),
#  ('HBL-010CDL:SC-PID-82304:Meas1_Name',
#   'HBL-010CDL:Cryo-PID-82304:Meas1_Name'),
#  ('HBL-010CDL:SC-PID-82304:Meas2_Name',
#   'HBL-010CDL:Cryo-PID-82304:Meas2_Name'),
#  ('HBL-010CDL:SC-PID-82304:Meas3_Name',
#   'HBL-010CDL:Cryo-PID-82304:Meas3_Name'),
#  ('HBL-010CDL:SC-PID-82305:PID_DIF', 'HBL-010CDL:Cryo-PID-82305:PID_DIF'),
#  ('HBL-010CDL:SC-PID-82305:PV', 'HBL-010CDL:Cryo-PID-82305:PV'),
#  ('HBL-010CDL:SC-PID-82305:MAN_SP', 'HBL-010CDL:Cryo-PID-82305:MAN_SP'),
#  ('HBL-010CDL:SC-PID-82305:FB_Setpoint',
#   'HBL-010CDL:Cryo-PID-82305:FB_Setpoint'),
#  ('HBL-010CDL:SC-PID-82306:LMN_P', 'HBL-010CDL:Cryo-PID-82306:LMN_P'),
#  ('HBL-010CDL:SC-PID-82306:ProcValueEGU',
#   'HBL-010CDL:Cryo-PID-82306:ProcValueEGU'),
#  ('HBL-010CDL:SC-PID-82306:MoveInterlock',
#   'HBL-010CDL:Cryo-PID-82306:MoveInterlock'),
#  ('HBL-010CDL:SC-PID-82306:FB_Setpoint',
#   'HBL-010CDL:Cryo-PID-82306:FB_Setpoint'),
#  ('HBL-010CDL:SC-PID-82360:LMN_D', 'HBL-010CDL:Cryo-PID-82360:LMN_D'),
#  ('HBL-010CDL:SC-PID-82360:PV', 'HBL-010CDL:Cryo-PID-82360:PV'),
#  ('HBL-010CDL:SC-PID-82360:MAN_SP', 'HBL-010CDL:Cryo-PID-82360:MAN_SP'),
#  ('HBL-010CDL:SC-PID-82361:LMN_D', 'HBL-010CDL:Cryo-PID-82361:LMN_D'),
#  ('HBL-010CDL:SC-PID-82361:ProcValueEGU',
#   'HBL-010CDL:Cryo-PID-82361:ProcValueEGU'),
#  ('HBL-010CDL:SC-PID-82361:FB_Step', 'HBL-010CDL:Cryo-PID-82361:FB_Step'),
#  ('HBL-010CDL:SC-PID-82361:FB_Manipulated',
#   'HBL-010CDL:Cryo-PID-82361:FB_Manipulated'),
#  ('HBL-010CDL:SC-PID-82362:LMN_D', 'HBL-010CDL:Cryo-PID-82362:LMN_D'),
#  ('HBL-010CDL:SC-PID-82362:MoveInterlock',
#   'HBL-010CDL:Cryo-PID-82362:MoveInterlock'),
#  ('HBL-010Crm:SC-PID-001:LMN_I', 'HBL-010Crm:SC-PID-001:LMN_I'),
#  ('HBL-010Crm:SC-PID-001:MAN_SP', 'HBL-010Crm:SC-PID-001:MAN_SP')]

# %%
archiver_linac = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %%
for from_pv, to_pv in failed_pvs:
    from_status = archiver_linac.get_archiving_status(from_pv)
    to_status = archiver_linac.get_archiving_status(to_pv)
    print(f"from {from_pv} is {from_status} to {to_pv} is {to_status}")
# Out:
# from HBL-010Crm:SC-FSM-700:ON is ArchivingStatus.NotBeingArchived to HBL-010Crm:SC-FSM-700:Opened is ArchivingStatus.NotBeingArchived
# from HBL-010Crm:SC-FSM-701:OpMode_Forced is ArchivingStatus.NotBeingArchived to HBL-010Crm:SC-FSM-700:OpMode_Manual is ArchivingStatus.BeingArchived
# from HBL-010Crm:SC-FSM-702:ON is ArchivingStatus.NotBeingArchived to HBL-010Crm:SC-FSM-702:Opened is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82303:MAN_SP is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82303:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82303:ProcValueName is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82303:ProcValueName is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82304:MAN_SP is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82304:Meas1_Name is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:Meas1_Name is ArchivingStatus.BeingArchived
# from HBL-010CDL:SC-PID-82304:Meas2_Name is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:Meas2_Name is ArchivingStatus.BeingArchived
# from HBL-010CDL:SC-PID-82304:Meas3_Name is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:Meas3_Name is ArchivingStatus.BeingArchived
# from HBL-010CDL:SC-PID-82305:PID_DIF is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82305:PID_DIF is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82305:PV is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82305:PV is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82305:MAN_SP is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82305:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82305:FB_Setpoint is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82305:FB_Setpoint is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:LMN_P is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82306:LMN_P is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:ProcValueEGU is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82306:ProcValueEGU is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:MoveInterlock is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82306:MoveInterlock is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:FB_Setpoint is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82306:FB_Setpoint is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82360:LMN_D is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82360:LMN_D is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82360:PV is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82360:PV is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82360:MAN_SP is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82360:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:LMN_D is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82361:LMN_D is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:ProcValueEGU is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82361:ProcValueEGU is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:FB_Step is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82361:FB_Step is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:FB_Manipulated is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82361:FB_Manipulated is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82362:LMN_D is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82362:LMN_D is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82362:MoveInterlock is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82362:MoveInterlock is ArchivingStatus.NotBeingArchived
# from HBL-010Crm:SC-PID-001:LMN_I is ArchivingStatus.NotBeingArchived to HBL-010Crm:SC-PID-001:LMN_I is ArchivingStatus.NotBeingArchived
# from HBL-010Crm:SC-PID-001:MAN_SP is ArchivingStatus.NotBeingArchived to HBL-010Crm:SC-PID-001:MAN_SP is ArchivingStatus.NotBeingArchived

# %%
for from_pv, to_pv in failed_pvs:
    print(from_pv)
    print(to_pv)
    print(f"{from_pv}_appendAlias_*")
# Out:
# HBL-010Crm:SC-FSM-700:ON
# HBL-010Crm:SC-FSM-700:Opened
# HBL-010Crm:SC-FSM-700:ON_appendAlias_*
# HBL-010Crm:SC-FSM-701:OpMode_Forced
# HBL-010Crm:SC-FSM-700:OpMode_Manual
# HBL-010Crm:SC-FSM-701:OpMode_Forced_appendAlias_*
# HBL-010Crm:SC-FSM-702:ON
# HBL-010Crm:SC-FSM-702:Opened
# HBL-010Crm:SC-FSM-702:ON_appendAlias_*
# HBL-010CDL:SC-PID-82303:MAN_SP
# HBL-010CDL:Cryo-PID-82303:MAN_SP
# HBL-010CDL:SC-PID-82303:MAN_SP_appendAlias_*
# HBL-010CDL:SC-PID-82303:ProcValueName
# HBL-010CDL:Cryo-PID-82303:ProcValueName
# HBL-010CDL:SC-PID-82303:ProcValueName_appendAlias_*
# HBL-010CDL:SC-PID-82304:MAN_SP
# HBL-010CDL:Cryo-PID-82304:MAN_SP
# HBL-010CDL:SC-PID-82304:MAN_SP_appendAlias_*
# HBL-010CDL:SC-PID-82304:Meas1_Name
# HBL-010CDL:Cryo-PID-82304:Meas1_Name
# HBL-010CDL:SC-PID-82304:Meas1_Name_appendAlias_*
# HBL-010CDL:SC-PID-82304:Meas2_Name
# HBL-010CDL:Cryo-PID-82304:Meas2_Name
# HBL-010CDL:SC-PID-82304:Meas2_Name_appendAlias_*
# HBL-010CDL:SC-PID-82304:Meas3_Name
# HBL-010CDL:Cryo-PID-82304:Meas3_Name
# HBL-010CDL:SC-PID-82304:Meas3_Name_appendAlias_*
# HBL-010CDL:SC-PID-82305:PID_DIF
# HBL-010CDL:Cryo-PID-82305:PID_DIF
# HBL-010CDL:SC-PID-82305:PID_DIF_appendAlias_*
# HBL-010CDL:SC-PID-82305:PV
# HBL-010CDL:Cryo-PID-82305:PV
# HBL-010CDL:SC-PID-82305:PV_appendAlias_*
# HBL-010CDL:SC-PID-82305:MAN_SP
# HBL-010CDL:Cryo-PID-82305:MAN_SP
# HBL-010CDL:SC-PID-82305:MAN_SP_appendAlias_*
# HBL-010CDL:SC-PID-82305:FB_Setpoint
# HBL-010CDL:Cryo-PID-82305:FB_Setpoint
# HBL-010CDL:SC-PID-82305:FB_Setpoint_appendAlias_*
# HBL-010CDL:SC-PID-82306:LMN_P
# HBL-010CDL:Cryo-PID-82306:LMN_P
# HBL-010CDL:SC-PID-82306:LMN_P_appendAlias_*
# HBL-010CDL:SC-PID-82306:ProcValueEGU
# HBL-010CDL:Cryo-PID-82306:ProcValueEGU
# HBL-010CDL:SC-PID-82306:ProcValueEGU_appendAlias_*
# HBL-010CDL:SC-PID-82306:MoveInterlock
# HBL-010CDL:Cryo-PID-82306:MoveInterlock
# HBL-010CDL:SC-PID-82306:MoveInterlock_appendAlias_*
# HBL-010CDL:SC-PID-82306:FB_Setpoint
# HBL-010CDL:Cryo-PID-82306:FB_Setpoint
# HBL-010CDL:SC-PID-82306:FB_Setpoint_appendAlias_*
# HBL-010CDL:SC-PID-82360:LMN_D
# HBL-010CDL:Cryo-PID-82360:LMN_D
# HBL-010CDL:SC-PID-82360:LMN_D_appendAlias_*
# HBL-010CDL:SC-PID-82360:PV
# HBL-010CDL:Cryo-PID-82360:PV
# HBL-010CDL:SC-PID-82360:PV_appendAlias_*
# HBL-010CDL:SC-PID-82360:MAN_SP
# HBL-010CDL:Cryo-PID-82360:MAN_SP
# HBL-010CDL:SC-PID-82360:MAN_SP_appendAlias_*
# HBL-010CDL:SC-PID-82361:LMN_D
# HBL-010CDL:Cryo-PID-82361:LMN_D
# HBL-010CDL:SC-PID-82361:LMN_D_appendAlias_*
# HBL-010CDL:SC-PID-82361:ProcValueEGU
# HBL-010CDL:Cryo-PID-82361:ProcValueEGU
# HBL-010CDL:SC-PID-82361:ProcValueEGU_appendAlias_*
# HBL-010CDL:SC-PID-82361:FB_Step
# HBL-010CDL:Cryo-PID-82361:FB_Step
# HBL-010CDL:SC-PID-82361:FB_Step_appendAlias_*
# HBL-010CDL:SC-PID-82361:FB_Manipulated
# HBL-010CDL:Cryo-PID-82361:FB_Manipulated
# HBL-010CDL:SC-PID-82361:FB_Manipulated_appendAlias_*
# HBL-010CDL:SC-PID-82362:LMN_D
# HBL-010CDL:Cryo-PID-82362:LMN_D
# HBL-010CDL:SC-PID-82362:LMN_D_appendAlias_*
# HBL-010CDL:SC-PID-82362:MoveInterlock
# HBL-010CDL:Cryo-PID-82362:MoveInterlock
# HBL-010CDL:SC-PID-82362:MoveInterlock_appendAlias_*
# HBL-010Crm:SC-PID-001:LMN_I
# HBL-010Crm:SC-PID-001:LMN_I
# HBL-010Crm:SC-PID-001:LMN_I_appendAlias_*
# HBL-010Crm:SC-PID-001:MAN_SP
# HBL-010Crm:SC-PID-001:MAN_SP
# HBL-010Crm:SC-PID-001:MAN_SP_appendAlias_*

# %%
path = "AS-243-followup/storagelog/pv_files_bkp-2025-01-28"
import re

def convert_to_filename(pv_name):
    return pv_name.replace(":", "/").replace("-", "/")

def title_pv_name(pv_name):
    return f"### pvNmae: {convert_to_filename(pv_name)}"

def find_linac_number(line):
    pattern = r"archiver-linac-(\d\d)"
    match = re.search(pattern, line)
    if match:
        return match.group(1)
    else:
        return None

def parse_file(path):
    result = {}
    with open(path, 'r') as f:
        pv = None
        for line in f:
            linac_number = find_linac_number(line)
            pv_name = [(from_pv, to_pv) for from_pv, to_pv in failed_pvs if title_pv_name(from_pv) in line or title_pv_name(to_pv) in line]
            if pv_name:
                from_pv, to_pv = pv_name[0]
                if convert_to_filename(from_pv) in line:
                   pv = from_pv
                elif convert_to_filename(to_pv) in line:
                   pv = to_pv
                print(f"pv_name: {pv_name}, pv: {pv}, linac_number: {linac_number}")

            if pv and linac_number:
                
                print(f"pv: {pv}, linac_number: {linac_number}")
                if linac_number:
                    result[pv] = linac_number
                pv = None
    return result

# %%
pvs_linacs = parse_file(path)
# Out:
# pv_name: [('HBL-010Crm:SC-FSM-700:ON', 'HBL-010Crm:SC-FSM-700:Opened')], pv: HBL-010Crm:SC-FSM-700:ON, linac_number: None
# pv: HBL-010Crm:SC-FSM-700:ON, linac_number: 12
# pv_name: [('HBL-010Crm:SC-FSM-700:ON', 'HBL-010Crm:SC-FSM-700:Opened')], pv: HBL-010Crm:SC-FSM-700:Opened, linac_number: None
# pv: HBL-010Crm:SC-FSM-700:Opened, linac_number: 14
# pv_name: [('HBL-010Crm:SC-FSM-700:ON', 'HBL-010Crm:SC-FSM-700:Opened')], pv: HBL-010Crm:SC-FSM-700:ON, linac_number: None
# pv_name: [('HBL-010Crm:SC-FSM-701:OpMode_Forced', 'HBL-010Crm:SC-FSM-700:OpMode_Manual')], pv: HBL-010Crm:SC-FSM-701:OpMode_Forced, linac_number: None
# pv: HBL-010Crm:SC-FSM-701:OpMode_Forced, linac_number: 09
# pv_name: [('HBL-010Crm:SC-FSM-701:OpMode_Forced', 'HBL-010Crm:SC-FSM-700:OpMode_Manual')], pv: HBL-010Crm:SC-FSM-700:OpMode_Manual, linac_number: None
# pv: HBL-010Crm:SC-FSM-700:OpMode_Manual, linac_number: 15
# pv_name: [('HBL-010Crm:SC-FSM-701:OpMode_Forced', 'HBL-010Crm:SC-FSM-700:OpMode_Manual')], pv: HBL-010Crm:SC-FSM-701:OpMode_Forced, linac_number: None
# pv_name: [('HBL-010Crm:SC-FSM-702:ON', 'HBL-010Crm:SC-FSM-702:Opened')], pv: HBL-010Crm:SC-FSM-702:ON, linac_number: None
# pv: HBL-010Crm:SC-FSM-702:ON, linac_number: 12
# pv_name: [('HBL-010Crm:SC-FSM-702:ON', 'HBL-010Crm:SC-FSM-702:Opened')], pv: HBL-010Crm:SC-FSM-702:Opened, linac_number: None
# pv: HBL-010Crm:SC-FSM-702:Opened, linac_number: 15
# pv_name: [('HBL-010Crm:SC-FSM-702:ON', 'HBL-010Crm:SC-FSM-702:Opened')], pv: HBL-010Crm:SC-FSM-702:ON, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82303:MAN_SP', 'HBL-010CDL:Cryo-PID-82303:MAN_SP')], pv: HBL-010CDL:SC-PID-82303:MAN_SP, linac_number: None
# pv: HBL-010CDL:SC-PID-82303:MAN_SP, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82303:MAN_SP', 'HBL-010CDL:Cryo-PID-82303:MAN_SP')], pv: HBL-010CDL:Cryo-PID-82303:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82303:MAN_SP', 'HBL-010CDL:Cryo-PID-82303:MAN_SP')], pv: HBL-010CDL:SC-PID-82303:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82303:ProcValueName', 'HBL-010CDL:Cryo-PID-82303:ProcValueName')], pv: HBL-010CDL:SC-PID-82303:ProcValueName, linac_number: None
# pv: HBL-010CDL:SC-PID-82303:ProcValueName, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82303:ProcValueName', 'HBL-010CDL:Cryo-PID-82303:ProcValueName')], pv: HBL-010CDL:Cryo-PID-82303:ProcValueName, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82303:ProcValueName', 'HBL-010CDL:Cryo-PID-82303:ProcValueName')], pv: HBL-010CDL:SC-PID-82303:ProcValueName, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:MAN_SP', 'HBL-010CDL:Cryo-PID-82304:MAN_SP')], pv: HBL-010CDL:SC-PID-82304:MAN_SP, linac_number: None
# pv: HBL-010CDL:SC-PID-82304:MAN_SP, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82304:MAN_SP', 'HBL-010CDL:Cryo-PID-82304:MAN_SP')], pv: HBL-010CDL:Cryo-PID-82304:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:MAN_SP', 'HBL-010CDL:Cryo-PID-82304:MAN_SP')], pv: HBL-010CDL:SC-PID-82304:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas1_Name', 'HBL-010CDL:Cryo-PID-82304:Meas1_Name')], pv: HBL-010CDL:SC-PID-82304:Meas1_Name, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas1_Name', 'HBL-010CDL:Cryo-PID-82304:Meas1_Name')], pv: HBL-010CDL:Cryo-PID-82304:Meas1_Name, linac_number: None
# pv: HBL-010CDL:Cryo-PID-82304:Meas1_Name, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas1_Name', 'HBL-010CDL:Cryo-PID-82304:Meas1_Name')], pv: HBL-010CDL:SC-PID-82304:Meas1_Name, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas2_Name', 'HBL-010CDL:Cryo-PID-82304:Meas2_Name')], pv: HBL-010CDL:SC-PID-82304:Meas2_Name, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas2_Name', 'HBL-010CDL:Cryo-PID-82304:Meas2_Name')], pv: HBL-010CDL:Cryo-PID-82304:Meas2_Name, linac_number: None
# pv: HBL-010CDL:Cryo-PID-82304:Meas2_Name, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas2_Name', 'HBL-010CDL:Cryo-PID-82304:Meas2_Name')], pv: HBL-010CDL:SC-PID-82304:Meas2_Name, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas3_Name', 'HBL-010CDL:Cryo-PID-82304:Meas3_Name')], pv: HBL-010CDL:SC-PID-82304:Meas3_Name, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas3_Name', 'HBL-010CDL:Cryo-PID-82304:Meas3_Name')], pv: HBL-010CDL:Cryo-PID-82304:Meas3_Name, linac_number: None
# pv: HBL-010CDL:Cryo-PID-82304:Meas3_Name, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82304:Meas3_Name', 'HBL-010CDL:Cryo-PID-82304:Meas3_Name')], pv: HBL-010CDL:SC-PID-82304:Meas3_Name, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:PID_DIF', 'HBL-010CDL:Cryo-PID-82305:PID_DIF')], pv: HBL-010CDL:SC-PID-82305:PID_DIF, linac_number: None
# pv: HBL-010CDL:SC-PID-82305:PID_DIF, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82305:PID_DIF', 'HBL-010CDL:Cryo-PID-82305:PID_DIF')], pv: HBL-010CDL:Cryo-PID-82305:PID_DIF, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:PID_DIF', 'HBL-010CDL:Cryo-PID-82305:PID_DIF')], pv: HBL-010CDL:SC-PID-82305:PID_DIF, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:PV', 'HBL-010CDL:Cryo-PID-82305:PV')], pv: HBL-010CDL:SC-PID-82305:PV, linac_number: None
# pv: HBL-010CDL:SC-PID-82305:PV, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82305:PV', 'HBL-010CDL:Cryo-PID-82305:PV')], pv: HBL-010CDL:Cryo-PID-82305:PV, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:PV', 'HBL-010CDL:Cryo-PID-82305:PV')], pv: HBL-010CDL:SC-PID-82305:PV, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:MAN_SP', 'HBL-010CDL:Cryo-PID-82305:MAN_SP')], pv: HBL-010CDL:SC-PID-82305:MAN_SP, linac_number: None
# pv: HBL-010CDL:SC-PID-82305:MAN_SP, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82305:MAN_SP', 'HBL-010CDL:Cryo-PID-82305:MAN_SP')], pv: HBL-010CDL:Cryo-PID-82305:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:MAN_SP', 'HBL-010CDL:Cryo-PID-82305:MAN_SP')], pv: HBL-010CDL:SC-PID-82305:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:FB_Setpoint', 'HBL-010CDL:Cryo-PID-82305:FB_Setpoint')], pv: HBL-010CDL:SC-PID-82305:FB_Setpoint, linac_number: None
# pv: HBL-010CDL:SC-PID-82305:FB_Setpoint, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82305:FB_Setpoint', 'HBL-010CDL:Cryo-PID-82305:FB_Setpoint')], pv: HBL-010CDL:Cryo-PID-82305:FB_Setpoint, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82305:FB_Setpoint', 'HBL-010CDL:Cryo-PID-82305:FB_Setpoint')], pv: HBL-010CDL:SC-PID-82305:FB_Setpoint, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:LMN_P', 'HBL-010CDL:Cryo-PID-82306:LMN_P')], pv: HBL-010CDL:SC-PID-82306:LMN_P, linac_number: None
# pv: HBL-010CDL:SC-PID-82306:LMN_P, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82306:LMN_P', 'HBL-010CDL:Cryo-PID-82306:LMN_P')], pv: HBL-010CDL:Cryo-PID-82306:LMN_P, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:LMN_P', 'HBL-010CDL:Cryo-PID-82306:LMN_P')], pv: HBL-010CDL:SC-PID-82306:LMN_P, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:ProcValueEGU', 'HBL-010CDL:Cryo-PID-82306:ProcValueEGU')], pv: HBL-010CDL:SC-PID-82306:ProcValueEGU, linac_number: None
# pv: HBL-010CDL:SC-PID-82306:ProcValueEGU, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82306:ProcValueEGU', 'HBL-010CDL:Cryo-PID-82306:ProcValueEGU')], pv: HBL-010CDL:Cryo-PID-82306:ProcValueEGU, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:ProcValueEGU', 'HBL-010CDL:Cryo-PID-82306:ProcValueEGU')], pv: HBL-010CDL:SC-PID-82306:ProcValueEGU, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:MoveInterlock', 'HBL-010CDL:Cryo-PID-82306:MoveInterlock')], pv: HBL-010CDL:SC-PID-82306:MoveInterlock, linac_number: None
# pv: HBL-010CDL:SC-PID-82306:MoveInterlock, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82306:MoveInterlock', 'HBL-010CDL:Cryo-PID-82306:MoveInterlock')], pv: HBL-010CDL:Cryo-PID-82306:MoveInterlock, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:MoveInterlock', 'HBL-010CDL:Cryo-PID-82306:MoveInterlock')], pv: HBL-010CDL:SC-PID-82306:MoveInterlock, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:FB_Setpoint', 'HBL-010CDL:Cryo-PID-82306:FB_Setpoint')], pv: HBL-010CDL:SC-PID-82306:FB_Setpoint, linac_number: None
# pv: HBL-010CDL:SC-PID-82306:FB_Setpoint, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82306:FB_Setpoint', 'HBL-010CDL:Cryo-PID-82306:FB_Setpoint')], pv: HBL-010CDL:Cryo-PID-82306:FB_Setpoint, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82306:FB_Setpoint', 'HBL-010CDL:Cryo-PID-82306:FB_Setpoint')], pv: HBL-010CDL:SC-PID-82306:FB_Setpoint, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82360:LMN_D', 'HBL-010CDL:Cryo-PID-82360:LMN_D')], pv: HBL-010CDL:SC-PID-82360:LMN_D, linac_number: None
# pv: HBL-010CDL:SC-PID-82360:LMN_D, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82360:LMN_D', 'HBL-010CDL:Cryo-PID-82360:LMN_D')], pv: HBL-010CDL:Cryo-PID-82360:LMN_D, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82360:LMN_D', 'HBL-010CDL:Cryo-PID-82360:LMN_D')], pv: HBL-010CDL:SC-PID-82360:LMN_D, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82360:PV', 'HBL-010CDL:Cryo-PID-82360:PV')], pv: HBL-010CDL:SC-PID-82360:PV, linac_number: None
# pv: HBL-010CDL:SC-PID-82360:PV, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82360:PV', 'HBL-010CDL:Cryo-PID-82360:PV')], pv: HBL-010CDL:Cryo-PID-82360:PV, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82360:PV', 'HBL-010CDL:Cryo-PID-82360:PV')], pv: HBL-010CDL:SC-PID-82360:PV, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82360:MAN_SP', 'HBL-010CDL:Cryo-PID-82360:MAN_SP')], pv: HBL-010CDL:SC-PID-82360:MAN_SP, linac_number: None
# pv: HBL-010CDL:SC-PID-82360:MAN_SP, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82360:MAN_SP', 'HBL-010CDL:Cryo-PID-82360:MAN_SP')], pv: HBL-010CDL:Cryo-PID-82360:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82360:MAN_SP', 'HBL-010CDL:Cryo-PID-82360:MAN_SP')], pv: HBL-010CDL:SC-PID-82360:MAN_SP, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:LMN_D', 'HBL-010CDL:Cryo-PID-82361:LMN_D')], pv: HBL-010CDL:SC-PID-82361:LMN_D, linac_number: None
# pv: HBL-010CDL:SC-PID-82361:LMN_D, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82361:LMN_D', 'HBL-010CDL:Cryo-PID-82361:LMN_D')], pv: HBL-010CDL:Cryo-PID-82361:LMN_D, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:LMN_D', 'HBL-010CDL:Cryo-PID-82361:LMN_D')], pv: HBL-010CDL:SC-PID-82361:LMN_D, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:ProcValueEGU', 'HBL-010CDL:Cryo-PID-82361:ProcValueEGU')], pv: HBL-010CDL:SC-PID-82361:ProcValueEGU, linac_number: None
# pv: HBL-010CDL:SC-PID-82361:ProcValueEGU, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82361:ProcValueEGU', 'HBL-010CDL:Cryo-PID-82361:ProcValueEGU')], pv: HBL-010CDL:Cryo-PID-82361:ProcValueEGU, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:ProcValueEGU', 'HBL-010CDL:Cryo-PID-82361:ProcValueEGU')], pv: HBL-010CDL:SC-PID-82361:ProcValueEGU, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:FB_Step', 'HBL-010CDL:Cryo-PID-82361:FB_Step')], pv: HBL-010CDL:SC-PID-82361:FB_Step, linac_number: None
# pv: HBL-010CDL:SC-PID-82361:FB_Step, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82361:FB_Step', 'HBL-010CDL:Cryo-PID-82361:FB_Step')], pv: HBL-010CDL:Cryo-PID-82361:FB_Step, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:FB_Step', 'HBL-010CDL:Cryo-PID-82361:FB_Step')], pv: HBL-010CDL:SC-PID-82361:FB_Step, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:FB_Manipulated', 'HBL-010CDL:Cryo-PID-82361:FB_Manipulated')], pv: HBL-010CDL:SC-PID-82361:FB_Manipulated, linac_number: None
# pv: HBL-010CDL:SC-PID-82361:FB_Manipulated, linac_number: 12
# pv_name: [('HBL-010CDL:SC-PID-82361:FB_Manipulated', 'HBL-010CDL:Cryo-PID-82361:FB_Manipulated')], pv: HBL-010CDL:Cryo-PID-82361:FB_Manipulated, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82361:FB_Manipulated', 'HBL-010CDL:Cryo-PID-82361:FB_Manipulated')], pv: HBL-010CDL:SC-PID-82361:FB_Manipulated, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82362:LMN_D', 'HBL-010CDL:Cryo-PID-82362:LMN_D')], pv: HBL-010CDL:SC-PID-82362:LMN_D, linac_number: None
# pv: HBL-010CDL:SC-PID-82362:LMN_D, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82362:LMN_D', 'HBL-010CDL:Cryo-PID-82362:LMN_D')], pv: HBL-010CDL:Cryo-PID-82362:LMN_D, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82362:LMN_D', 'HBL-010CDL:Cryo-PID-82362:LMN_D')], pv: HBL-010CDL:SC-PID-82362:LMN_D, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82362:MoveInterlock', 'HBL-010CDL:Cryo-PID-82362:MoveInterlock')], pv: HBL-010CDL:SC-PID-82362:MoveInterlock, linac_number: None
# pv: HBL-010CDL:SC-PID-82362:MoveInterlock, linac_number: 09
# pv_name: [('HBL-010CDL:SC-PID-82362:MoveInterlock', 'HBL-010CDL:Cryo-PID-82362:MoveInterlock')], pv: HBL-010CDL:Cryo-PID-82362:MoveInterlock, linac_number: None
# pv_name: [('HBL-010CDL:SC-PID-82362:MoveInterlock', 'HBL-010CDL:Cryo-PID-82362:MoveInterlock')], pv: HBL-010CDL:SC-PID-82362:MoveInterlock, linac_number: None
# pv_name: [('HBL-010Crm:SC-PID-001:LMN_I', 'HBL-010Crm:SC-PID-001:LMN_I')], pv: HBL-010Crm:SC-PID-001:LMN_I, linac_number: None
# pv: HBL-010Crm:SC-PID-001:LMN_I, linac_number: 09
# pv_name: [('HBL-010Crm:SC-PID-001:LMN_I', 'HBL-010Crm:SC-PID-001:LMN_I')], pv: HBL-010Crm:SC-PID-001:LMN_I, linac_number: None
# pv: HBL-010Crm:SC-PID-001:LMN_I, linac_number: 09
# pv_name: [('HBL-010Crm:SC-PID-001:LMN_I', 'HBL-010Crm:SC-PID-001:LMN_I')], pv: HBL-010Crm:SC-PID-001:LMN_I, linac_number: None
# pv_name: [('HBL-010Crm:SC-PID-001:MAN_SP', 'HBL-010Crm:SC-PID-001:MAN_SP')], pv: HBL-010Crm:SC-PID-001:MAN_SP, linac_number: None
# pv: HBL-010Crm:SC-PID-001:MAN_SP, linac_number: 09
# pv_name: [('HBL-010Crm:SC-PID-001:MAN_SP', 'HBL-010Crm:SC-PID-001:MAN_SP')], pv: HBL-010Crm:SC-PID-001:MAN_SP, linac_number: None
# pv: HBL-010Crm:SC-PID-001:MAN_SP, linac_number: 09
# pv_name: [('HBL-010Crm:SC-PID-001:MAN_SP', 'HBL-010Crm:SC-PID-001:MAN_SP')], pv: HBL-010Crm:SC-PID-001:MAN_SP, linac_number: None

# %%
pvs_linacs
# Out:
# {'HBL-010Crm:SC-FSM-700:ON': '12',
#  'HBL-010Crm:SC-FSM-700:Opened': '14',
#  'HBL-010Crm:SC-FSM-701:OpMode_Forced': '09',
#  'HBL-010Crm:SC-FSM-700:OpMode_Manual': '15',
#  'HBL-010Crm:SC-FSM-702:ON': '12',
#  'HBL-010Crm:SC-FSM-702:Opened': '15',
#  'HBL-010CDL:SC-PID-82303:MAN_SP': '09',
#  'HBL-010CDL:SC-PID-82303:ProcValueName': '09',
#  'HBL-010CDL:SC-PID-82304:MAN_SP': '12',
#  'HBL-010CDL:Cryo-PID-82304:Meas1_Name': '09',
#  'HBL-010CDL:Cryo-PID-82304:Meas2_Name': '12',
#  'HBL-010CDL:Cryo-PID-82304:Meas3_Name': '12',
#  'HBL-010CDL:SC-PID-82305:PID_DIF': '12',
#  'HBL-010CDL:SC-PID-82305:PV': '12',
#  'HBL-010CDL:SC-PID-82305:MAN_SP': '12',
#  'HBL-010CDL:SC-PID-82305:FB_Setpoint': '12',
#  'HBL-010CDL:SC-PID-82306:LMN_P': '12',
#  'HBL-010CDL:SC-PID-82306:ProcValueEGU': '12',
#  'HBL-010CDL:SC-PID-82306:MoveInterlock': '12',
#  'HBL-010CDL:SC-PID-82306:FB_Setpoint': '12',
#  'HBL-010CDL:SC-PID-82360:LMN_D': '09',
#  'HBL-010CDL:SC-PID-82360:PV': '12',
#  'HBL-010CDL:SC-PID-82360:MAN_SP': '09',
#  'HBL-010CDL:SC-PID-82361:LMN_D': '12',
#  'HBL-010CDL:SC-PID-82361:ProcValueEGU': '12',
#  'HBL-010CDL:SC-PID-82361:FB_Step': '09',
#  'HBL-010CDL:SC-PID-82361:FB_Manipulated': '12',
#  'HBL-010CDL:SC-PID-82362:LMN_D': '09',
#  'HBL-010CDL:SC-PID-82362:MoveInterlock': '09',
#  'HBL-010Crm:SC-PID-001:LMN_I': '09',
#  'HBL-010Crm:SC-PID-001:MAN_SP': '09'}

# %%
for pv, linac in pvs_linacs.items():
    appliance_name = f"archiver-linac-{linac}"
    archiver_linac.archive_pv(pv, appliance=appliance_name)

# %%
for from_pv, to_pv in failed_pvs:
    from_status = archiver_linac.get_archiving_status(from_pv)
    to_status = archiver_linac.get_archiving_status(to_pv)
    print(f"from {from_pv} is {from_status} to {to_pv} is {to_status}")
# Out:
# from HBL-010Crm:SC-FSM-700:ON is ArchivingStatus.BeingArchived to HBL-010Crm:SC-FSM-700:Opened is None
# from HBL-010Crm:SC-FSM-701:OpMode_Forced is ArchivingStatus.BeingArchived to HBL-010Crm:SC-FSM-700:OpMode_Manual is ArchivingStatus.BeingArchived
# from HBL-010Crm:SC-FSM-702:ON is ArchivingStatus.BeingArchived to HBL-010Crm:SC-FSM-702:Opened is None
# from HBL-010CDL:SC-PID-82303:MAN_SP is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82303:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82303:ProcValueName is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82303:ProcValueName is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82304:MAN_SP is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82304:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82304:Meas1_Name is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:Meas1_Name is ArchivingStatus.BeingArchived
# from HBL-010CDL:SC-PID-82304:Meas2_Name is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:Meas2_Name is ArchivingStatus.BeingArchived
# from HBL-010CDL:SC-PID-82304:Meas3_Name is ArchivingStatus.NotBeingArchived to HBL-010CDL:Cryo-PID-82304:Meas3_Name is ArchivingStatus.BeingArchived
# from HBL-010CDL:SC-PID-82305:PID_DIF is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82305:PID_DIF is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82305:PV is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82305:PV is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82305:MAN_SP is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82305:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82305:FB_Setpoint is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82305:FB_Setpoint is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:LMN_P is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82306:LMN_P is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:ProcValueEGU is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82306:ProcValueEGU is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:MoveInterlock is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82306:MoveInterlock is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82306:FB_Setpoint is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82306:FB_Setpoint is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82360:LMN_D is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82360:LMN_D is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82360:PV is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82360:PV is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82360:MAN_SP is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82360:MAN_SP is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:LMN_D is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82361:LMN_D is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:ProcValueEGU is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82361:ProcValueEGU is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:FB_Step is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82361:FB_Step is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82361:FB_Manipulated is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82361:FB_Manipulated is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82362:LMN_D is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82362:LMN_D is ArchivingStatus.NotBeingArchived
# from HBL-010CDL:SC-PID-82362:MoveInterlock is ArchivingStatus.BeingArchived to HBL-010CDL:Cryo-PID-82362:MoveInterlock is ArchivingStatus.NotBeingArchived
# from HBL-010Crm:SC-PID-001:LMN_I is ArchivingStatus.BeingArchived to HBL-010Crm:SC-PID-001:LMN_I is ArchivingStatus.BeingArchived
# from HBL-010Crm:SC-PID-001:MAN_SP is ArchivingStatus.BeingArchived to HBL-010Crm:SC-PID-001:MAN_SP is ArchivingStatus.BeingArchived

# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    filename="logs/mgmt_operations.as_243_followup.log",
    encoding="utf-8",
)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
need_to_be_renamed = [
 ('HBL-010CDL:SC-PID-82304:Meas1_Name',
  'HBL-010CDL:Cryo-PID-82304:Meas1_Name'),
 ('HBL-010CDL:SC-PID-82304:Meas2_Name',
  'HBL-010CDL:Cryo-PID-82304:Meas2_Name'),
 ('HBL-010CDL:SC-PID-82304:Meas3_Name',
  'HBL-010CDL:Cryo-PID-82304:Meas3_Name'),]

# %%
for to_pv, from_pv in need_to_be_renamed:
    from_status = archiver_linac.get_archiving_status(from_pv)
    to_status = archiver_linac.get_archiving_status(to_pv)
    LOG.info(f"from {from_pv} is {from_status} to {to_pv} is {to_status}")

# %%
def simple_rename(pvs_renames, archiver_linac_tn):
    """
    Simple rename
    """
    for new_pv, old_pv in pvs_renames:
        LOG.info(f"Renaming {old_pv} to {new_pv}")
        new_pv_status = archiver_linac_tn.get_archiving_status(new_pv)
        LOG.info(f"New PV status: {new_pv_status}")
        archiver_linac_tn.pause_rename_resume_pv(old_pv, new_pv)
        LOG.info(f"Renamed {old_pv} to {new_pv}")

# %%
simple_rename(need_to_be_renamed, archiver_linac)

# %%
for to_pv, from_pv in need_to_be_renamed:
    from_status = archiver_linac.get_archiving_status(from_pv)
    to_status = archiver_linac.get_archiving_status(to_pv)
    LOG.info(f"from {from_pv} is {from_status} to {to_pv} is {to_status}")
