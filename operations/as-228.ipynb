# %% [markdown]
# # Mgmt Operations

# %% [markdown]
# ## Init Stuff

# %%
import logging
from rich.logging import RichHandler

format_msg = "%(message)s"

level = logging.INFO
tracebacks = False

logging.basicConfig(
    level=level,
    format=format_msg,
    datefmt="[%X]",
    handlers=[RichHandler(rich_tracebacks=tracebacks)],

)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
from epicsarchiver import ArchiverAppliance

# %%
from epicsarchiver.common import ArchDbrType

# %%
archiver_linac_tn = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %% [markdown]
# ## Changes

# %% [markdown]
# ### [AS-228](https://jira.ess.eu/browse/AS-228)

# %% [markdown]
# #### Sampling period to 1 Hz

# %%
input_text = """
 ############################################################
+## Spk-000CDL:Cryo-PLC-010
 # The module version
+Spk-000CDL:Cryo-PLC-010:ModVersionR
 # Modbus connection state
+Spk-000CDL:Cryo-PLC-010:ModbusConnectedR
 # S7 connection state
+Spk-000CDL:Cryo-PLC-010:S7ConnectedR
 # Address of the PLC
+Spk-000CDL:Cryo-PLC-010:PLCAddr-RB
 # Global connection state
+Spk-000CDL:Cryo-PLC-010:ConnectedR
 # Hash correctness state
+Spk-000CDL:Cryo-PLC-010:PLCHashCorrectR
 # PLC liveliness

+Spk-000CDL:Cryo-PLC-010:AliveR
 # IOC Hash
+Spk-000CDL:Cryo-PLC-010:CommsHashToPLC
 # PLC Hash
+Spk-000CDL:Cryo-PLC-010:CommsHashFromPLCR
 # Configured payload size
-# Payload size configured on the PLC 
+Spk-000CDL:Cryo-PLC-010:PayloadSizeR
+# Payload size configured on the PLC
+Spk-000CDL:Cryo-PLC-010:PayloadSizeFromPLCR
 # Payload size configuration correctness state
+Spk-000CDL:Cryo-PLC-010:PayloadSizeCorrectR
 ############################################################
+## Spk-000CDL:Cryo-PLC-010
 # All parameters Zero
+Spk-000CDL:Cryo-PLC-010:ParametersFrozen
 # CMD: Acknowledge Alarm
+Spk-000CDL:Cryo-PLC-010:Cmd_AckAlarm
 # CMD: Unlock Parameter Freeze
+Spk-000CDL:Cryo-PLC-010:Cmd_ParamFreeze_OFF
 ############################################################
 ## Spk-000CDL:SC-FSM-400
 # Value of VGC1000
+Spk-000CDL:SC-FSM-400:CavityVac1 1Hz
 # Value of VGC2000
+Spk-000CDL:SC-FSM-400:CavityVac2 1Hz
 # Value of VGC3000
+Spk-000CDL:SC-FSM-400:CavityVac3 1Hz
 # Value of VGC4000
+Spk-000CDL:SC-FSM-400:CavityVac4 1Hz
 # Value of VGC01100
+Spk-000CDL:SC-FSM-400:CMGaugeIsoVac1 1Hz
 # Value of VGP01100
+Spk-000CDL:SC-FSM-400:CMGaugeIsoVac2 1Hz
+############################################################

 ############################################################
 ## Spk-000CDL:
 # VacumOK
+Spk-000CDL::VacOK1
 # VacumOK
+Spk-000CDL::VacOK2
 # Interlock in CTL Cryo Ready
+Spk-000CDL::CDS_Cryo_Ready
 # Interlock in CTL Cryo OK
+Spk-000CDL::CDS_Cryo_OK
 # Start Interlock
+Spk-000CDL::StartInterlock
 # Stop Interlock
+Spk-000CDL::StopInterlock
+Spk-000CDL::ReadDI_Others_001
+Spk-000CDL::ReadDI_Others_002
+Spk-000CDL::ReadDI_Others_003
+Spk-000CDL::ReadDI_Others_004
+Spk-000CDL::ReadDI_Others_005
+Spk-000CDL::ReadDI_Others_006
+Spk-000CDL::ReadDI_Others_007
+Spk-000CDL::ReadDI_Others_008
+Spk-000CDL::ReadDI_Others_009
+Spk-000CDL::ReadDI_Others_010
 # WF Flush ON

+Spk-000CDL::Flushing_ON
 # WF Flush OFF

+Spk-000CDL::Flushing_OFF
 # WF Flush Mode Auto

+Spk-000CDL::WF_OpMode_Auto
 # WF Flush  Mode Manual

+Spk-000CDL::WF_OpMode_Manual
 # WF Flush  Mode Forced

+Spk-000CDL::WF_OpMode_Forced
 # WF Conditions reached

+Spk-000CDL::WF_FlushCond_01
 # WF Conditions reached

+Spk-000CDL::WF_FlushCond_02
 # WF Conditions reached

+Spk-000CDL::WF_FlushCond_03
 # WF Conditions reached

+Spk-000CDL::WF_FlushCond_04
 # WF Circuit 1 Blowed

+Spk-000CDL::WF_Blowed_01
 # WF Circuit 2 Blowed

+Spk-000CDL::WF_Blowed_02
 # WF Circuit 3 Blowed

+Spk-000CDL::WF_Blowed_03
 # WF Circuit 4 Blowed

+Spk-000CDL::WF_Blowed_04
 # CMD: Auto Mode

+Spk-000CDL::Cmd_WF_Auto 1Hz
 # CMD: Manual Mode

+Spk-000CDL::Cmd_WF_Manual 1Hz
 # CMD: Force Mode

+Spk-000CDL::Cmd_WF_Force 1Hz
 # CMD: Manual Open

+Spk-000CDL::Cmd_WF_ManuOpen 1Hz
 # CMD: Manual Close

+Spk-000CDL::Cmd_WF_ManuClose 1Hz
 # CMD: Force Open

+Spk-000CDL::Cmd_WF_ForceOpen 1Hz
 # CMD: Force Close

+Spk-000CDL::Cmd_WF_ForceClose 1Hz
 # CMD: Acknowledge All Alarms

+Spk-000CDL::Cmd_WF_AckAlarm 1Hz
 # VacumOK1_FromEndbox

+Spk-000CDL::VacOK1_EB 1Hz
 # VacumOK2_FromEndbox

+Spk-000CDL::VacOK2_EB 1Hz
 # VacumOK1_FromEndbox

+Spk-000CDL::P_retentivemode 1Hz

############################################################
 ## Spk-000CDL:Cryo-CV-91
 # Operation Mode Auto

+Spk-000CDL:Cryo-CV-91:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-CV-91:OpMode_Manual
 # Operation Mode Forced

+Spk-000CDL:Cryo-CV-91:OpMode_Forced
 # Valve Position AI

+Spk-000CDL:Cryo-CV-91:ValvePosition
 # Valve Setpoint

+Spk-000CDL:Cryo-CV-91:ValveSP
 # Valve Control AO

+Spk-000CDL:Cryo-CV-91:ValveMV
 # Move Interlock

+Spk-000CDL:Cryo-CV-91:MoveInterlock
 # Position Discrepancy

+Spk-000CDL:Cryo-CV-91:Position_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-CV-91:IO_Error
 # HW Output Module Error

+Spk-000CDL:Cryo-CV-91:Module_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-CV-91:FB_Setpoint
 ############################################################
 ## Spk-000CDL:Cryo-CV-92
 # Operation Mode Auto

+Spk-000CDL:Cryo-CV-92:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-CV-92:OpMode_Manual
 # Operation Mode Forced

+Spk-000CDL:Cryo-CV-92:OpMode_Forced
 # Valve Position AI

+Spk-000CDL:Cryo-CV-92:ValvePosition
 # Valve Setpoint

+Spk-000CDL:Cryo-CV-92:ValveSP
 # Valve Control AO

+Spk-000CDL:Cryo-CV-92:ValveMV
 # Move Interlock

+Spk-000CDL:Cryo-CV-92:MoveInterlock
 # Position Discrepancy

+Spk-000CDL:Cryo-CV-92:Position_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-CV-92:IO_Error
 # HW Output Module Error

+Spk-000CDL:Cryo-CV-92:Module_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-CV-92:FB_Setpoint
 ############################################################
 ## Spk-000CDL:Cryo-CV-93
 # Operation Mode Auto

+Spk-000CDL:Cryo-CV-93:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-CV-93:OpMode_Manual
 # Operation Mode Forced

+Spk-000CDL:Cryo-CV-93:OpMode_Forced
 # Valve Position AI

+Spk-000CDL:Cryo-CV-93:ValvePosition
 # Valve Setpoint

+Spk-000CDL:Cryo-CV-93:ValveSP
 # Valve Control AO

+Spk-000CDL:Cryo-CV-93:ValveMV
 # Move Interlock

+Spk-000CDL:Cryo-CV-93:MoveInterlock
 # Position Discrepancy

+Spk-000CDL:Cryo-CV-93:Position_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-CV-93:IO_Error
 # HW Output Module Error

+Spk-000CDL:Cryo-CV-93:Module_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-CV-93:FB_Setpoint
 ############################################################
 ## Spk-000CDL:Cryo-CV-94
 # Operation Mode Auto

+Spk-000CDL:Cryo-CV-94:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-CV-94:OpMode_Manual
 # Operation Mode Forced

+Spk-000CDL:Cryo-CV-94:OpMode_Forced
 # Valve Position AI

+Spk-000CDL:Cryo-CV-94:ValvePosition
 # Valve Setpoint

+Spk-000CDL:Cryo-CV-94:ValveSP
 # Valve Control AO

+Spk-000CDL:Cryo-CV-94:ValveMV
 # Move Interlock

+Spk-000CDL:Cryo-CV-94:MoveInterlock
 # Position Discrepancy

+Spk-000CDL:Cryo-CV-94:Position_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-CV-94:IO_Error
 # HW Output Module Error

+Spk-000CDL:Cryo-CV-94:Module_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-CV-94:FB_Setpoint
 ############################################################
 ## Spk-000CDL:Cryo-PI-001
 # Operation Mode Auto

+Spk-000CDL:Cryo-PI-001:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-PI-001:OpMode_Manual
 # Opened

+Spk-000CDL:Cryo-PI-001:Opened
 # Closed

+Spk-000CDL:Cryo-PI-001:Closed
 ############################################################
 ## Spk-000CDL:Cryo-PI-002
 # Operation Mode Auto

+Spk-000CDL:Cryo-PI-002:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-PI-002:OpMode_Manual
 # Opened

+Spk-000CDL:Cryo-PI-002:Opened
 # Closed

+Spk-000CDL:Cryo-PI-002:Closed
 ############################################################
 ## Spk-000CDL:Cryo-XZ-001
 # Operation Mode Auto

+Spk-000CDL:Cryo-XZ-001:OpMode_Auto
 # Operation Mode Manual

+Spk-000CDL:Cryo-XZ-001:OpMode_Manual
 # Opened

+Spk-000CDL:Cryo-XZ-001:Opened
 # Closed

+Spk-000CDL:Cryo-XZ-001:Closed
 ############################################################
 ## Spk-000CDL:Cryo-TC-001
 # TotalEH Resistance

 ############################################################
 ## Spk-000CDL:Cryo-EH-910
 # Heater Resistance

+Spk-000CDL:Cryo-EH-910:HeaterResistance
 # Heater Current AI

+Spk-000CDL:Cryo-EH-910:HeaterCurrent
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-910:HeaterVoltage
 # Heater Power

+Spk-000CDL:Cryo-EH-910:HeaterPower
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-910:HeaterSP
 # Heater Control

+Spk-000CDL:Cryo-EH-910:HeaterMV
 # Heater Current AI

+Spk-000CDL:Cryo-EH-910:PSU_Current
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-910:PSU_Voltage
 # Heater Power

+Spk-000CDL:Cryo-EH-910:PSU_Power
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-910:PSU_SP
 # Manipulated Value

+Spk-000CDL:Cryo-EH-910:LMN
 # Manipulated Value P-Action

+Spk-000CDL:Cryo-EH-910:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL:Cryo-EH-910:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL:Cryo-EH-910:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL:Cryo-EH-910:PID_DIF
 # PID Process Value

+Spk-000CDL:Cryo-EH-910:PV
 # PID Setpoint Value

+Spk-000CDL:Cryo-EH-910:MAN_SP
 # Heat Interlock

+Spk-000CDL:Cryo-EH-910:HeatInterlock
 # Ramping Indicator

+Spk-000CDL:Cryo-EH-910:Ramping
 # during operation

+Spk-000CDL:Cryo-EH-910:In_Scanning
 # Connected

+Spk-000CDL:Cryo-EH-910:Connected
 # Heater operating

+Spk-000CDL:Cryo-EH-910:PSU_Status
 # Heater Control AO

+Spk-000CDL:Cryo-EH-910:PSU_MV
 # Double load configuration

+Spk-000CDL:Cryo-EH-910:FB_DoubleLoad
 # Double load configuration

+Spk-000CDL:Cryo-EH-910:FB_SingleLoad
 # relay 1 in use

+Spk-000CDL:Cryo-EH-910:FB_Relay1
 # relay 2 in use

+Spk-000CDL:Cryo-EH-910:FB_Relay2
 # Default load mode

+Spk-000CDL:Cryo-EH-910:FB_DefaultMode
 # Heater resistance  1

+Spk-000CDL:Cryo-EH-910:EHResistanceScan1
 # MB device Unit ID

+Spk-000CDL:Cryo-EH-910:UnitID
 # Heater Voltage

+Spk-000CDL:Cryo-EH-910:PSU_MAX_SP
 # Heater Current

+Spk-000CDL:Cryo-EH-910:PSU_MAX_CURR
 # Heater Voltage

+Spk-000CDL:Cryo-EH-910:PSU_MAX_VOLT
 # check if in remote mode

+Spk-000CDL:Cryo-EH-910:Remote
 # Treshold_ON

+Spk-000CDL:Cryo-EH-910:Threshold_ON
 # Status ReadBack

+Spk-000CDL:Cryo-EH-910:ReadBack_Status
 # Status write cmd on

+Spk-000CDL:Cryo-EH-910:PowerCmd_Status
 # Status write cmd parameters

+Spk-000CDL:Cryo-EH-910:ParameterCmd_Status
 # Error Status ReadBack

+Spk-000CDL:Cryo-EH-910:ReadBackErr_Status
 # Error Status write cmd on

+Spk-000CDL:Cryo-EH-910:PowerCmdErr_Status
 # Error Status write cmd parameters

+Spk-000CDL:Cryo-EH-910:ParamCmdErr_Status
 # Heater Power Discrepancy

+Spk-000CDL:Cryo-EH-910:Power_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-EH-910:IO_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-EH-910:FB_Setpoint
 # Cmd Force conncet

+Spk-000CDL:Cryo-EH-910:Cmd_Connected
 # clearing MB client faults

+Spk-000CDL:Cryo-EH-910:Cmd_Clear_faults
 # get diagnostics button

+Spk-000CDL:Cryo-EH-910:Cmd_Diag
 # Turn Ramping ON

+Spk-000CDL:Cryo-EH-910:Cmd_RampON
 # Turn Ramping OFF

+Spk-000CDL:Cryo-EH-910:Cmd_RampOFF
 # CMD: ON Mode

+Spk-000CDL:Cryo-EH-910:Cmd_ON
 # CMD: OFF Mode

+Spk-000CDL:Cryo-EH-910:Cmd_OFF
 # Cmd Double load

+Spk-000CDL:Cryo-EH-910:Cmd_DoubleLoad
 # Cmd single load

+Spk-000CDL:Cryo-EH-910:Cmd_SingleLoad
 # relay 1 ON/OFF

+Spk-000CDL:Cryo-EH-910:Cmd_Relay1
 # relay 2 ON/OFF

+Spk-000CDL:Cryo-EH-910:Cmd_Relay2
 # command treshold ON

+Spk-000CDL:Cryo-EH-910:Cmd_Threshold_ON
 # command treshold OFF

+Spk-000CDL:Cryo-EH-910:Cmd_Threshold_OFF
 # Scan loads

+Spk-000CDL:Cryo-EH-910:Cmd_Scan
 # High inductance

+Spk-000CDL:Cryo-EH-910:P_Manual_Interlock
 # Ramping UP Time

+Spk-000CDL:Cryo-EH-910:P_RampUPTIME
 # Ramping UP Range

+Spk-000CDL:Cryo-EH-910:P_RampUPRANGE
 # Ramping DOWN Time

+Spk-000CDL:Cryo-EH-910:P_RampDNTIME
 # Ramping DOWN Range

+Spk-000CDL:Cryo-EH-910:P_RampDNRANGE
 ############################################################
 ## Spk-000CDL:Cryo-EH-920
 # Heater Resistance

+Spk-000CDL:Cryo-EH-920:HeaterResistance
 # Heater Current AI

+Spk-000CDL:Cryo-EH-920:HeaterCurrent
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-920:HeaterVoltage
 # Heater Power

+Spk-000CDL:Cryo-EH-920:HeaterPower
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-920:HeaterSP
 # Heater Control

+Spk-000CDL:Cryo-EH-920:HeaterMV
 # Heater Current AI

+Spk-000CDL:Cryo-EH-920:PSU_Current
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-920:PSU_Voltage
 # Heater Power

+Spk-000CDL:Cryo-EH-920:PSU_Power
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-920:PSU_SP
 # Manipulated Value

+Spk-000CDL:Cryo-EH-920:LMN
 # Manipulated Value P-Action

+Spk-000CDL:Cryo-EH-920:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL:Cryo-EH-920:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL:Cryo-EH-920:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL:Cryo-EH-920:PID_DIF
 # PID Process Value

+Spk-000CDL:Cryo-EH-920:PV
 # PID Setpoint Value

+Spk-000CDL:Cryo-EH-920:MAN_SP
 # Heat Interlock

+Spk-000CDL:Cryo-EH-920:HeatInterlock
 # Ramping Indicator

+Spk-000CDL:Cryo-EH-920:Ramping
 # during operation

+Spk-000CDL:Cryo-EH-920:In_Scanning
 # Connected

+Spk-000CDL:Cryo-EH-920:Connected
 # Heater operating

+Spk-000CDL:Cryo-EH-920:PSU_Status
 # Heater Control AO

+Spk-000CDL:Cryo-EH-920:PSU_MV
 # Double load configuration

+Spk-000CDL:Cryo-EH-920:FB_DoubleLoad
 # Double load configuration

+Spk-000CDL:Cryo-EH-920:FB_SingleLoad
 # relay 1 in use

+Spk-000CDL:Cryo-EH-920:FB_Relay1
 # relay 2 in use

+Spk-000CDL:Cryo-EH-920:FB_Relay2
 # Default load mode

+Spk-000CDL:Cryo-EH-920:FB_DefaultMode
 # Heater resistance  1

+Spk-000CDL:Cryo-EH-920:EHResistanceScan1
 # MB device Unit ID

+Spk-000CDL:Cryo-EH-920:UnitID
 # Heater Voltage

+Spk-000CDL:Cryo-EH-920:PSU_MAX_SP
 # Heater Current

+Spk-000CDL:Cryo-EH-920:PSU_MAX_CURR
 # Heater Voltage

+Spk-000CDL:Cryo-EH-920:PSU_MAX_VOLT
 # check if in remote mode

+Spk-000CDL:Cryo-EH-920:Remote
 # Treshold_ON

+Spk-000CDL:Cryo-EH-920:Threshold_ON
 # Status ReadBack

+Spk-000CDL:Cryo-EH-920:ReadBack_Status
 # Status write cmd on

+Spk-000CDL:Cryo-EH-920:PowerCmd_Status
 # Status write cmd parameters

+Spk-000CDL:Cryo-EH-920:ParameterCmd_Status
 # Error Status ReadBack

+Spk-000CDL:Cryo-EH-920:ReadBackErr_Status
 # Error Status write cmd on

+Spk-000CDL:Cryo-EH-920:PowerCmdErr_Status
 # Error Status write cmd parameters

+Spk-000CDL:Cryo-EH-920:ParamCmdErr_Status
 # Heater Power Discrepancy

+Spk-000CDL:Cryo-EH-920:Power_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-EH-920:IO_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-EH-920:FB_Setpoint
 # Cmd Force conncet

+Spk-000CDL:Cryo-EH-920:Cmd_Connected
 # clearing MB client faults

+Spk-000CDL:Cryo-EH-920:Cmd_Clear_faults
 # get diagnostics button

+Spk-000CDL:Cryo-EH-920:Cmd_Diag
 # Turn Ramping ON

+Spk-000CDL:Cryo-EH-920:Cmd_RampON
 # Turn Ramping OFF

+Spk-000CDL:Cryo-EH-920:Cmd_RampOFF
 # CMD: ON Mode

+Spk-000CDL:Cryo-EH-920:Cmd_ON
 # CMD: OFF Mode

+Spk-000CDL:Cryo-EH-920:Cmd_OFF
 # Cmd Double load

+Spk-000CDL:Cryo-EH-920:Cmd_DoubleLoad
 # Cmd single load

+Spk-000CDL:Cryo-EH-920:Cmd_SingleLoad
 # relay 1 ON/OFF

+Spk-000CDL:Cryo-EH-920:Cmd_Relay1
 # relay 2 ON/OFF

+Spk-000CDL:Cryo-EH-920:Cmd_Relay2
 # command treshold ON

+Spk-000CDL:Cryo-EH-920:Cmd_Threshold_ON
 # command treshold OFF

+Spk-000CDL:Cryo-EH-920:Cmd_Threshold_OFF
 # Scan loads

+Spk-000CDL:Cryo-EH-920:Cmd_Scan
 # High inductance

+Spk-000CDL:Cryo-EH-920:P_Manual_Interlock
 # Ramping UP Time

+Spk-000CDL:Cryo-EH-920:P_RampUPTIME
 # Ramping UP Range

+Spk-000CDL:Cryo-EH-920:P_RampUPRANGE
 # Ramping DOWN Time

+Spk-000CDL:Cryo-EH-920:P_RampDNTIME
 # Ramping DOWN Range

+Spk-000CDL:Cryo-EH-920:P_RampDNRANGE
 ############################################################
 ## Spk-000CDL:Cryo-EH-930
 # Heater Resistance

+Spk-000CDL:Cryo-EH-930:HeaterResistance
 # Heater Current AI

+Spk-000CDL:Cryo-EH-930:HeaterCurrent
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-930:HeaterVoltage
 # Heater Power

+Spk-000CDL:Cryo-EH-930:HeaterPower
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-930:HeaterSP
 # Heater Control

+Spk-000CDL:Cryo-EH-930:HeaterMV
 # Heater Current AI

+Spk-000CDL:Cryo-EH-930:PSU_Current
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-930:PSU_Voltage
 # Heater Power

+Spk-000CDL:Cryo-EH-930:PSU_Power
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-930:PSU_SP
 # Manipulated Value

+Spk-000CDL:Cryo-EH-930:LMN
 # Manipulated Value P-Action

+Spk-000CDL:Cryo-EH-930:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL:Cryo-EH-930:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL:Cryo-EH-930:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL:Cryo-EH-930:PID_DIF
 # PID Process Value

+Spk-000CDL:Cryo-EH-930:PV
 # PID Setpoint Value

+Spk-000CDL:Cryo-EH-930:MAN_SP
 # Heat Interlock

+Spk-000CDL:Cryo-EH-930:HeatInterlock
 # Ramping Indicator

+Spk-000CDL:Cryo-EH-930:Ramping
 # during operation

+Spk-000CDL:Cryo-EH-930:In_Scanning
 # Connected

+Spk-000CDL:Cryo-EH-930:Connected
 # Heater operating

+Spk-000CDL:Cryo-EH-930:PSU_Status
 # Heater Control AO

+Spk-000CDL:Cryo-EH-930:PSU_MV
 # Double load configuration

+Spk-000CDL:Cryo-EH-930:FB_DoubleLoad
 # Double load configuration

+Spk-000CDL:Cryo-EH-930:FB_SingleLoad
 # relay 1 in use

+Spk-000CDL:Cryo-EH-930:FB_Relay1
 # relay 2 in use

+Spk-000CDL:Cryo-EH-930:FB_Relay2
 # Default load mode

+Spk-000CDL:Cryo-EH-930:FB_DefaultMode
 # Heater resistance  1

+Spk-000CDL:Cryo-EH-930:EHResistanceScan1
 # MB device Unit ID

+Spk-000CDL:Cryo-EH-930:UnitID
 # Heater Voltage

+Spk-000CDL:Cryo-EH-930:PSU_MAX_SP
 # Heater Current

+Spk-000CDL:Cryo-EH-930:PSU_MAX_CURR
 # Heater Voltage

+Spk-000CDL:Cryo-EH-930:PSU_MAX_VOLT
 # check if in remote mode

+Spk-000CDL:Cryo-EH-930:Remote
 # Treshold_ON

+Spk-000CDL:Cryo-EH-930:Threshold_ON
 # Status ReadBack

+Spk-000CDL:Cryo-EH-930:ReadBack_Status
 # Status write cmd on

+Spk-000CDL:Cryo-EH-930:PowerCmd_Status
 # Status write cmd parameters

+Spk-000CDL:Cryo-EH-930:ParameterCmd_Status
 # Error Status ReadBack

+Spk-000CDL:Cryo-EH-930:ReadBackErr_Status
 # Error Status write cmd on

+Spk-000CDL:Cryo-EH-930:PowerCmdErr_Status
 # Error Status write cmd parameters

+Spk-000CDL:Cryo-EH-930:ParamCmdErr_Status
 # Heater Power Discrepancy

+Spk-000CDL:Cryo-EH-930:Power_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-EH-930:IO_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-EH-930:FB_Setpoint
 # Cmd Force conncet

+Spk-000CDL:Cryo-EH-930:Cmd_Connected
 # clearing MB client faults

+Spk-000CDL:Cryo-EH-930:Cmd_Clear_faults
 # get diagnostics button

+Spk-000CDL:Cryo-EH-930:Cmd_Diag
 # Turn Ramping ON

+Spk-000CDL:Cryo-EH-930:Cmd_RampON
 # Turn Ramping OFF

+Spk-000CDL:Cryo-EH-930:Cmd_RampOFF
 # CMD: ON Mode

+Spk-000CDL:Cryo-EH-930:Cmd_ON
 # CMD: OFF Mode

+Spk-000CDL:Cryo-EH-930:Cmd_OFF
 # Cmd Double load

+Spk-000CDL:Cryo-EH-930:Cmd_DoubleLoad
 # Cmd single load

+Spk-000CDL:Cryo-EH-930:Cmd_SingleLoad
 # relay 1 ON/OFF

+Spk-000CDL:Cryo-EH-930:Cmd_Relay1
 # relay 2 ON/OFF

+Spk-000CDL:Cryo-EH-930:Cmd_Relay2
 # command treshold ON

+Spk-000CDL:Cryo-EH-930:Cmd_Threshold_ON
 # command treshold OFF

+Spk-000CDL:Cryo-EH-930:Cmd_Threshold_OFF
 # Scan loads

+Spk-000CDL:Cryo-EH-930:Cmd_Scan
 # High inductance

+Spk-000CDL:Cryo-EH-930:P_Manual_Interlock
 # Ramping UP Time

+Spk-000CDL:Cryo-EH-930:P_RampUPTIME
 # Ramping UP Range

+Spk-000CDL:Cryo-EH-930:P_RampUPRANGE
 # Ramping DOWN Time

+Spk-000CDL:Cryo-EH-930:P_RampDNTIME
 # Ramping DOWN Range

+Spk-000CDL:Cryo-EH-930:P_RampDNRANGE
 ############################################################
 ## Spk-000CDL:Cryo-EH-940
 # Heater Resistance

+Spk-000CDL:Cryo-EH-940:HeaterResistance
 # Heater Current AI

+Spk-000CDL:Cryo-EH-940:HeaterCurrent
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-940:HeaterVoltage
 # Heater Power

+Spk-000CDL:Cryo-EH-940:HeaterPower
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-940:HeaterSP
 # Heater Control

+Spk-000CDL:Cryo-EH-940:HeaterMV
 # Heater Current AI

+Spk-000CDL:Cryo-EH-940:PSU_Current
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-940:PSU_Voltage
 # Heater Power

+Spk-000CDL:Cryo-EH-940:PSU_Power
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-940:PSU_SP
 # Manipulated Value

+Spk-000CDL:Cryo-EH-940:LMN
 # Manipulated Value P-Action

+Spk-000CDL:Cryo-EH-940:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL:Cryo-EH-940:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL:Cryo-EH-940:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL:Cryo-EH-940:PID_DIF
 # PID Process Value

+Spk-000CDL:Cryo-EH-940:PV
 # PID Setpoint Value

+Spk-000CDL:Cryo-EH-940:MAN_SP
 # Heat Interlock

+Spk-000CDL:Cryo-EH-940:HeatInterlock
 # Ramping Indicator

+Spk-000CDL:Cryo-EH-940:Ramping
 # during operation

+Spk-000CDL:Cryo-EH-940:In_Scanning
 # Connected

+Spk-000CDL:Cryo-EH-940:Connected
 # Heater operating

+Spk-000CDL:Cryo-EH-940:PSU_Status
 # Heater Control AO

+Spk-000CDL:Cryo-EH-940:PSU_MV
 # Double load configuration

+Spk-000CDL:Cryo-EH-940:FB_DoubleLoad
 # Double load configuration

+Spk-000CDL:Cryo-EH-940:FB_SingleLoad
 # relay 1 in use

+Spk-000CDL:Cryo-EH-940:FB_Relay1
 # relay 2 in use

+Spk-000CDL:Cryo-EH-940:FB_Relay2
 # Default load mode

+Spk-000CDL:Cryo-EH-940:FB_DefaultMode
 # Heater resistance  1

+Spk-000CDL:Cryo-EH-940:EHResistanceScan1
 # MB device Unit ID

+Spk-000CDL:Cryo-EH-940:UnitID
 # Heater Voltage

+Spk-000CDL:Cryo-EH-940:PSU_MAX_SP
 # Heater Current

+Spk-000CDL:Cryo-EH-940:PSU_MAX_CURR
 # Heater Voltage

+Spk-000CDL:Cryo-EH-940:PSU_MAX_VOLT
 # check if in remote mode

+Spk-000CDL:Cryo-EH-940:Remote
 # Treshold_ON

+Spk-000CDL:Cryo-EH-940:Threshold_ON
 # Status ReadBack

+Spk-000CDL:Cryo-EH-940:ReadBack_Status
 # Status write cmd on

+Spk-000CDL:Cryo-EH-940:PowerCmd_Status
 # Status write cmd parameters

+Spk-000CDL:Cryo-EH-940:ParameterCmd_Status
 # Error Status ReadBack

+Spk-000CDL:Cryo-EH-940:ReadBackErr_Status
 # Error Status write cmd on

+Spk-000CDL:Cryo-EH-940:PowerCmdErr_Status
 # Error Status write cmd parameters

+Spk-000CDL:Cryo-EH-940:ParamCmdErr_Status
 # Heater Power Discrepancy

+Spk-000CDL:Cryo-EH-940:Power_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-EH-940:IO_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-EH-940:FB_Setpoint
 # Cmd Force conncet

+Spk-000CDL:Cryo-EH-940:Cmd_Connected
 # clearing MB client faults

+Spk-000CDL:Cryo-EH-940:Cmd_Clear_faults
 # get diagnostics button

+Spk-000CDL:Cryo-EH-940:Cmd_Diag
 # Turn Ramping ON

+Spk-000CDL:Cryo-EH-940:Cmd_RampON
 # Turn Ramping OFF

+Spk-000CDL:Cryo-EH-940:Cmd_RampOFF
 # CMD: ON Mode

+Spk-000CDL:Cryo-EH-940:Cmd_ON
 # CMD: OFF Mode

+Spk-000CDL:Cryo-EH-940:Cmd_OFF
 # Cmd Double load

+Spk-000CDL:Cryo-EH-940:Cmd_DoubleLoad
 # Cmd single load

+Spk-000CDL:Cryo-EH-940:Cmd_SingleLoad
 # relay 1 ON/OFF

+Spk-000CDL:Cryo-EH-940:Cmd_Relay1
 # relay 2 ON/OFF

+Spk-000CDL:Cryo-EH-940:Cmd_Relay2
 # command treshold ON

+Spk-000CDL:Cryo-EH-940:Cmd_Threshold_ON
 # command treshold OFF

+Spk-000CDL:Cryo-EH-940:Cmd_Threshold_OFF
 # Scan loads

+Spk-000CDL:Cryo-EH-940:Cmd_Scan
 # High inductance

+Spk-000CDL:Cryo-EH-940:P_Manual_Interlock
 # Ramping UP Time

+Spk-000CDL:Cryo-EH-940:P_RampUPTIME
 # Ramping UP Range

+Spk-000CDL:Cryo-EH-940:P_RampUPRANGE
 # Ramping DOWN Time

+Spk-000CDL:Cryo-EH-940:P_RampDNTIME
 # Ramping DOWN Range

+Spk-000CDL:Cryo-EH-940:P_RampDNRANGE
 ############################################################
 ## Spk-000CDL:Cryo-EH-950
 # Heater Resistance

+Spk-000CDL:Cryo-EH-950:HeaterResistance
 # Heater Current AI

+Spk-000CDL:Cryo-EH-950:HeaterCurrent
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-950:HeaterVoltage
 # Heater Power

+Spk-000CDL:Cryo-EH-950:HeaterPower
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-950:HeaterSP
 # Heater Control

+Spk-000CDL:Cryo-EH-950:HeaterMV
 # Heater Current AI

+Spk-000CDL:Cryo-EH-950:PSU_Current
 # Heater Voltage AI

+Spk-000CDL:Cryo-EH-950:PSU_Voltage
 # Heater Power

+Spk-000CDL:Cryo-EH-950:PSU_Power
 # Heater Setpoint

+Spk-000CDL:Cryo-EH-950:PSU_SP
 # Manipulated Value

+Spk-000CDL:Cryo-EH-950:LMN
 # Manipulated Value P-Action

+Spk-000CDL:Cryo-EH-950:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL:Cryo-EH-950:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL:Cryo-EH-950:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL:Cryo-EH-950:PID_DIF
 # PID Process Value

+Spk-000CDL:Cryo-EH-950:PV
 # PID Setpoint Value

+Spk-000CDL:Cryo-EH-950:MAN_SP
 # Heat Interlock

+Spk-000CDL:Cryo-EH-950:HeatInterlock
 # Ramping Indicator

+Spk-000CDL:Cryo-EH-950:Ramping
 # during operation

+Spk-000CDL:Cryo-EH-950:In_Scanning
 # Connected

+Spk-000CDL:Cryo-EH-950:Connected
 # Heater operating

+Spk-000CDL:Cryo-EH-950:PSU_Status
 # Heater Control AO

+Spk-000CDL:Cryo-EH-950:PSU_MV
 # Double load configuration

+Spk-000CDL:Cryo-EH-950:FB_DoubleLoad
 # Double load configuration

+Spk-000CDL:Cryo-EH-950:FB_SingleLoad
 # relay 1 in use

+Spk-000CDL:Cryo-EH-950:FB_Relay1
 # relay 2 in use

+Spk-000CDL:Cryo-EH-950:FB_Relay2
 # Default load mode

+Spk-000CDL:Cryo-EH-950:FB_DefaultMode
 # Heater resistance  1

+Spk-000CDL:Cryo-EH-950:EHResistanceScan1
 # MB device Unit ID

+Spk-000CDL:Cryo-EH-950:UnitID
 # Heater Voltage

+Spk-000CDL:Cryo-EH-950:PSU_MAX_SP
 # Heater Current

+Spk-000CDL:Cryo-EH-950:PSU_MAX_CURR
 # Heater Voltage

+Spk-000CDL:Cryo-EH-950:PSU_MAX_VOLT
 # check if in remote mode

+Spk-000CDL:Cryo-EH-950:Remote
 # Treshold_ON

+Spk-000CDL:Cryo-EH-950:Threshold_ON
 # Status ReadBack

+Spk-000CDL:Cryo-EH-950:ReadBack_Status
 # Status write cmd on

+Spk-000CDL:Cryo-EH-950:PowerCmd_Status
 # Status write cmd parameters

+Spk-000CDL:Cryo-EH-950:ParameterCmd_Status
 # Error Status ReadBack

+Spk-000CDL:Cryo-EH-950:ReadBackErr_Status
 # Error Status write cmd on

+Spk-000CDL:Cryo-EH-950:PowerCmdErr_Status
 # Error Status write cmd parameters

+Spk-000CDL:Cryo-EH-950:ParamCmdErr_Status
 # Heater Power Discrepancy

+Spk-000CDL:Cryo-EH-950:Power_Discrep
 # HW IO Error

+Spk-000CDL:Cryo-EH-950:IO_Error
 # FB Setpoint from HMI (SP)

+Spk-000CDL:Cryo-EH-950:FB_Setpoint
 # Cmd Force conncet

+Spk-000CDL:Cryo-EH-950:Cmd_Connected
 # clearing MB client faults

+Spk-000CDL:Cryo-EH-950:Cmd_Clear_faults
 # get diagnostics button

+Spk-000CDL:Cryo-EH-950:Cmd_Diag
 # Turn Ramping ON

+Spk-000CDL:Cryo-EH-950:Cmd_RampON
 # Turn Ramping OFF

+Spk-000CDL:Cryo-EH-950:Cmd_RampOFF
 # CMD: ON Mode

+Spk-000CDL:Cryo-EH-950:Cmd_ON
 # CMD: OFF Mode

+Spk-000CDL:Cryo-EH-950:Cmd_OFF
 # Cmd Double load

+Spk-000CDL:Cryo-EH-950:Cmd_DoubleLoad
 # Cmd single load

+Spk-000CDL:Cryo-EH-950:Cmd_SingleLoad
 # relay 1 ON/OFF

+Spk-000CDL:Cryo-EH-950:Cmd_Relay1
 # relay 2 ON/OFF

+Spk-000CDL:Cryo-EH-950:Cmd_Relay2
 # command treshold ON

+Spk-000CDL:Cryo-EH-950:Cmd_Threshold_ON
 # command treshold OFF

+Spk-000CDL:Cryo-EH-950:Cmd_Threshold_OFF
 # Scan loads

+Spk-000CDL:Cryo-EH-950:Cmd_Scan
 # High inductance

+Spk-000CDL:Cryo-EH-950:P_Manual_Interlock
 # Ramping UP Time

+Spk-000CDL:Cryo-EH-950:P_RampUPTIME
 # Ramping UP Range

+Spk-000CDL:Cryo-EH-950:P_RampUPRANGE
 # Ramping DOWN Time

+Spk-000CDL:Cryo-EH-950:P_RampDNTIME
 # Ramping DOWN Range

+Spk-000CDL:Cryo-EH-950:P_RampDNRANGE
 ############################################################
 ## Spk-000CDL:Cryo-HV-70
 # Valve Opened

+Spk-000CDL:Cryo-HV-70:Opened
 # Valve Closed

+Spk-000CDL:Cryo-HV-70:Closed
 ############################################################
 ## Spk-000CDL:Cryo-HV-73
 # Valve Opened

+Spk-000CDL:Cryo-HV-73:Opened
 # Valve Closed

+Spk-000CDL:Cryo-HV-73:Closed
 ############################################################
 ## Spk-000CDL:Cryo-TT-91
 # Temperature Value

+Spk-000CDL:Cryo-TT-91:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-91:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-91:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-91:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-91:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-91:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-91:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-92
 # Temperature Value

+Spk-000CDL:Cryo-TT-92:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-92:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-92:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-92:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-92:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-92:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-92:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-93
 # Temperature Value

+Spk-000CDL:Cryo-TT-93:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-93:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-93:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-93:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-93:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-93:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-93:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-94
 # Temperature Value

+Spk-000CDL:Cryo-TT-94:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-94:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-94:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-94:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-94:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-94:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-94:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-95
 # Temperature Value

+Spk-000CDL:Cryo-TT-95:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-95:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-95:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-95:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-95:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-95:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-95:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-96
 # Temperature Value

+Spk-000CDL:Cryo-TT-96:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-96:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-96:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-96:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-96:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-96:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-96:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-97
 # Temperature Value

+Spk-000CDL:Cryo-TT-97:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-97:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-97:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-97:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-97:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-97:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-97:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-TT-98
 # Temperature Value

+Spk-000CDL:Cryo-TT-98:MeasValue 1Hz
 # Temperature Underrange

+Spk-000CDL:Cryo-TT-98:Underrange
 # Temperature Overrange

+Spk-000CDL:Cryo-TT-98:Overrange
 # Temperature HIHI

+Spk-000CDL:Cryo-TT-98:HIHI
 # Temperature LOLO

+Spk-000CDL:Cryo-TT-98:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-TT-98:Param_Error
 # LakeShore Profibus Error

+Spk-000CDL:Cryo-TT-98:PN_Module_Error
 ############################################################
 ## Spk-000CDL:Cryo-LT-91
 # Level Value

+Spk-000CDL:Cryo-LT-91:MeasValue 1Hz
 # RAW integer scaled

+Spk-000CDL:Cryo-LT-91:RAWValue 1Hz
+# Offset Value
+Spk-000CDL:Cryo-LT-91:OffsetValue
 # Alarm Status Relay

+Spk-000CDL:Cryo-LT-91:AlarmRelay
+# Start LC Measurement
+Spk-000CDL:Cryo-LT-91:LCMeasS
 # Level Underrange

+Spk-000CDL:Cryo-LT-91:Underrange
 # Level Overrange

+Spk-000CDL:Cryo-LT-91:Overrange
 # Level HIHI

+Spk-000CDL:Cryo-LT-91:HIHI
 # Level LOLO

+Spk-000CDL:Cryo-LT-91:LOLO
 # Module_Error

+Spk-000CDL:Cryo-LT-91:Module_Error
 # Parameter_Error

+Spk-000CDL:Cryo-LT-91:Param_Error
+# Warm_Sensor
+Spk-000CDL:Cryo-LT-91:Warm_Sensor
 ############################################################
 ## Spk-000CDL:Cryo-LT-92
 # Level Value

+Spk-000CDL:Cryo-LT-92:MeasValue 1Hz
 # RAW integer scaled

+Spk-000CDL:Cryo-LT-92:RAWValue 1Hz
+# Offset Value
+Spk-000CDL:Cryo-LT-92:OffsetValue
 # Alarm Status Relay

+Spk-000CDL:Cryo-LT-92:AlarmRelay
+# Start LC Measurement
+Spk-000CDL:Cryo-LT-92:LCMeasS
 # Level Underrange

+Spk-000CDL:Cryo-LT-92:Underrange
 # Level Overrange

+Spk-000CDL:Cryo-LT-92:Overrange
 # Level HIHI

+Spk-000CDL:Cryo-LT-92:HIHI
 # Level LOLO

+Spk-000CDL:Cryo-LT-92:LOLO
 # Module_Error

+Spk-000CDL:Cryo-LT-92:Module_Error
 # Parameter_Error

+Spk-000CDL:Cryo-LT-92:Param_Error
+# Warm_Sensor
+Spk-000CDL:Cryo-LT-92:Warm_Sensor
 ############################################################
-## Spk-000CDL:Cryo-PID-93
+## Spk-000CDL-910
 # Selected Measurement

+Spk-000CDL-910:SelectedPV
 # Manipulated Value

+Spk-000CDL-910:LMN
 # Manipulated Value P-Action

+Spk-000CDL-910:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL-910:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL-910:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL-910:PID_DIF
 # PID Process Value

+Spk-000CDL-910:PV
 # PID Setpoint Value

+Spk-000CDL-910:MAN_SP
 # PV Name of the Process Value

+Spk-000CDL-910:ProcValueName
 # EGU of the Process Value

+Spk-000CDL-910:ProcValueEGU
 # 1st Select Measurement

+Spk-000CDL-910:Meas1_Name
 # 2nd Select Measurement

+Spk-000CDL-910:Meas2_Name
 # 3rd Select Measurement

+Spk-000CDL-910:Meas3_Name
 # Move Interlock

+Spk-000CDL-910:MoveInterlock
 # FB Setpoint from HMI (SP)

+Spk-000CDL-910:FB_Setpoint
 # FB Step value for Open/Close

+Spk-000CDL-910:FB_Step
 # Force Manipulated value (AO)

+Spk-000CDL-910:FB_Manipulated
 # FB Proportional gain

+Spk-000CDL-910:FB_Gain 1Hz
 # FB Integration time

+Spk-000CDL-910:FB_TI 1Hz
 # FB Derivative action time

+Spk-000CDL-910:FB_TD 1Hz
 # FB Deadband

+Spk-000CDL-910:FB_DEADB 1Hz
 # FB High limit for MV

+Spk-000CDL-910:FB_LMN_HLIM 1Hz
 # FB Low limit for MV

+Spk-000CDL-910:FB_LMN_LLIM 1Hz
 # FB Proportional gain

+Spk-000CDL-910:FB_Gain_1 1Hz
 # FB Integration time

+Spk-000CDL-910:FB_TI_1 1Hz
 # FB Derivative action time

+Spk-000CDL-910:FB_TD_1 1Hz
 # FB Deadband

+Spk-000CDL-910:FB_DEADB_1 1Hz
 # FB High limit for MV

+Spk-000CDL-910:FB_LMN_HLIM_1 1Hz
 # FB Low limit for MV

+Spk-000CDL-910:FB_LMN_LLIM_1 1Hz
 # FB Proportional gain

+Spk-000CDL-910:FB_Gain_2 1Hz
 # FB Integration time

+Spk-000CDL-910:FB_TI_2 1Hz
 # FB Derivative action time

+Spk-000CDL-910:FB_TD_2 1Hz
 # FB Deadband

+Spk-000CDL-910:FB_DEADB_2 1Hz
 # FB High limit for MV

+Spk-000CDL-910:FB_LMN_HLIM_2 1Hz
 # FB Low limit for MV

+Spk-000CDL-910:FB_LMN_LLIM_2 1Hz
 # FB Proportional gain

+Spk-000CDL-910:FB_Gain_3 1Hz
 # FB Integration time

+Spk-000CDL-910:FB_TI_3 1Hz
 # FB Derivative action time

+Spk-000CDL-910:FB_TD_3 1Hz
 # FB Deadband

+Spk-000CDL-910:FB_DEADB_3 1Hz
 # FB High limit for MV

+Spk-000CDL-910:FB_LMN_HLIM_3 1Hz
 # FB Low limit for MV

+Spk-000CDL-910:FB_LMN_LLIM_3 1Hz
 ############################################################
-## Spk-000CDL:Cryo-PID-930
+## Spk-000CDL-920
 # Selected Measurement

+Spk-000CDL-920:SelectedPV
 # Manipulated Value

+Spk-000CDL-920:LMN
 # Manipulated Value P-Action

+Spk-000CDL-920:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL-920:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL-920:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL-920:PID_DIF
 # PID Process Value

+Spk-000CDL-920:PV
 # PID Setpoint Value

+Spk-000CDL-920:MAN_SP
 # PV Name of the Process Value

+Spk-000CDL-920:ProcValueName
 # EGU of the Process Value

+Spk-000CDL-920:ProcValueEGU
 # 1st Select Measurement

+Spk-000CDL-920:Meas1_Name
 # 2nd Select Measurement

+Spk-000CDL-920:Meas2_Name
 # 3rd Select Measurement

+Spk-000CDL-920:Meas3_Name
 # Move Interlock

+Spk-000CDL-920:MoveInterlock
 # FB Setpoint from HMI (SP)

+Spk-000CDL-920:FB_Setpoint
 # FB Step value for Open/Close

+Spk-000CDL-920:FB_Step
 # Force Manipulated value (AO)

+Spk-000CDL-920:FB_Manipulated
 # FB Proportional gain

+Spk-000CDL-920:FB_Gain 1Hz
 # FB Integration time

+Spk-000CDL-920:FB_TI 1Hz
 # FB Derivative action time

+Spk-000CDL-920:FB_TD 1Hz
 # FB Deadband

+Spk-000CDL-920:FB_DEADB 1Hz
 # FB High limit for MV

+Spk-000CDL-920:FB_LMN_HLIM 1Hz
 # FB Low limit for MV

+Spk-000CDL-920:FB_LMN_LLIM 1Hz
 # FB Proportional gain

+Spk-000CDL-920:FB_Gain_1 1Hz
 # FB Integration time

+Spk-000CDL-920:FB_TI_1 1Hz
 # FB Derivative action time

+Spk-000CDL-920:FB_TD_1 1Hz
 # FB Deadband

+Spk-000CDL-920:FB_DEADB_1 1Hz
 # FB High limit for MV

+Spk-000CDL-920:FB_LMN_HLIM_1 1Hz
 # FB Low limit for MV

+Spk-000CDL-920:FB_LMN_LLIM_1 1Hz
 # FB Proportional gain

+Spk-000CDL-920:FB_Gain_2 1Hz
 # FB Integration time

+Spk-000CDL-920:FB_TI_2 1Hz
 # FB Derivative action time

+Spk-000CDL-920:FB_TD_2 1Hz
 # FB Deadband

+Spk-000CDL-920:FB_DEADB_2 1Hz
 # FB High limit for MV

+Spk-000CDL-920:FB_LMN_HLIM_2 1Hz
 # FB Low limit for MV

+Spk-000CDL-920:FB_LMN_LLIM_2 1Hz
 # FB Proportional gain

+Spk-000CDL-920:FB_Gain_3 1Hz
 # FB Integration time

+Spk-000CDL-920:FB_TI_3 1Hz
 # FB Derivative action time

+Spk-000CDL-920:FB_TD_3 1Hz
 # FB Deadband

+Spk-000CDL-920:FB_DEADB_3 1Hz
 # FB High limit for MV

+Spk-000CDL-920:FB_LMN_HLIM_3 1Hz
 # FB Low limit for MV

+Spk-000CDL-920:FB_LMN_LLIM_3 1Hz
 ############################################################
-## Spk-000CDL:Cryo-PID-94
+## Spk-000CDL-930
 # Selected Measurement

+Spk-000CDL-930:SelectedPV
 # Manipulated Value

+Spk-000CDL-930:LMN
 # Manipulated Value P-Action

+Spk-000CDL-930:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL-930:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL-930:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL-930:PID_DIF
 # PID Process Value

+Spk-000CDL-930:PV
 # PID Setpoint Value

+Spk-000CDL-930:MAN_SP
 # PV Name of the Process Value

+Spk-000CDL-930:ProcValueName
 # EGU of the Process Value

+Spk-000CDL-930:ProcValueEGU
 # 1st Select Measurement

+Spk-000CDL-930:Meas1_Name
 # 2nd Select Measurement

+Spk-000CDL-930:Meas2_Name
 # 3rd Select Measurement

+Spk-000CDL-930:Meas3_Name
 # Move Interlock

+Spk-000CDL-930:MoveInterlock
 # FB Setpoint from HMI (SP)

+Spk-000CDL-930:FB_Setpoint
 # FB Step value for Open/Close

+Spk-000CDL-930:FB_Step
 # Force Manipulated value (AO)

+Spk-000CDL-930:FB_Manipulated
 # FB Proportional gain

+Spk-000CDL-930:FB_Gain 1Hz
 # FB Integration time

+Spk-000CDL-930:FB_TI 1Hz
 # FB Derivative action time

+Spk-000CDL-930:FB_TD 1Hz
 # FB Deadband

+Spk-000CDL-930:FB_DEADB 1Hz
 # FB High limit for MV

+Spk-000CDL-930:FB_LMN_HLIM 1Hz
 # FB Low limit for MV

+Spk-000CDL-930:FB_LMN_LLIM 1Hz
 # FB Proportional gain

+Spk-000CDL-930:FB_Gain_1 1Hz
 # FB Integration time

+Spk-000CDL-930:FB_TI_1 1Hz
 # FB Derivative action time

+Spk-000CDL-930:FB_TD_1 1Hz
 # FB Deadband

+Spk-000CDL-930:FB_DEADB_1 1Hz
 # FB High limit for MV

+Spk-000CDL-930:FB_LMN_HLIM_1 1Hz
 # FB Low limit for MV

+Spk-000CDL-930:FB_LMN_LLIM_1 1Hz
 # FB Proportional gain

+Spk-000CDL-930:FB_Gain_2 1Hz
 # FB Integration time

+Spk-000CDL-930:FB_TI_2 1Hz
 # FB Derivative action time

+Spk-000CDL-930:FB_TD_2 1Hz
 # FB Deadband

+Spk-000CDL-930:FB_DEADB_2 1Hz
 # FB High limit for MV

+Spk-000CDL-930:FB_LMN_HLIM_2 1Hz
 # FB Low limit for MV

+Spk-000CDL-930:FB_LMN_LLIM_2 1Hz
 # FB Proportional gain

+Spk-000CDL-930:FB_Gain_3 1Hz
 # FB Integration time

+Spk-000CDL-930:FB_TI_3 1Hz
 # FB Derivative action time

+Spk-000CDL-930:FB_TD_3 1Hz
 # FB Deadband

+Spk-000CDL-930:FB_DEADB_3 1Hz
 # FB High limit for MV

+Spk-000CDL-930:FB_LMN_HLIM_3 1Hz
 # FB Low limit for MV

+Spk-000CDL-930:FB_LMN_LLIM_3 1Hz
 ############################################################
-## Spk-000CDL:Cryo-PID-940
+## Spk-000CDL-940
 # Selected Measurement

+Spk-000CDL-940:SelectedPV
 # Manipulated Value

+Spk-000CDL-940:LMN
 # Manipulated Value P-Action

+Spk-000CDL-940:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL-940:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL-940:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL-940:PID_DIF
 # PID Process Value

+Spk-000CDL-940:PV
 # PID Setpoint Value

+Spk-000CDL-940:MAN_SP
 # PV Name of the Process Value

+Spk-000CDL-940:ProcValueName
 # EGU of the Process Value

+Spk-000CDL-940:ProcValueEGU
 # 1st Select Measurement

+Spk-000CDL-940:Meas1_Name
 # 2nd Select Measurement

+Spk-000CDL-940:Meas2_Name
 # 3rd Select Measurement

+Spk-000CDL-940:Meas3_Name
 # Move Interlock

+Spk-000CDL-940:MoveInterlock
 # FB Setpoint from HMI (SP)

+Spk-000CDL-940:FB_Setpoint
 # FB Step value for Open/Close

+Spk-000CDL-940:FB_Step
 # Force Manipulated value (AO)

+Spk-000CDL-940:FB_Manipulated
 # FB Proportional gain

+Spk-000CDL-940:FB_Gain 1Hz
 # FB Integration time

+Spk-000CDL-940:FB_TI 1Hz
 # FB Derivative action time

+Spk-000CDL-940:FB_TD 1Hz
 # FB Deadband

+Spk-000CDL-940:FB_DEADB 1Hz
 # FB High limit for MV

+Spk-000CDL-940:FB_LMN_HLIM 1Hz
 # FB Low limit for MV

+Spk-000CDL-940:FB_LMN_LLIM 1Hz
 # FB Proportional gain

+Spk-000CDL-940:FB_Gain_1 1Hz
 # FB Integration time

+Spk-000CDL-940:FB_TI_1 1Hz
 # FB Derivative action time

+Spk-000CDL-940:FB_TD_1 1Hz
 # FB Deadband

+Spk-000CDL-940:FB_DEADB_1 1Hz
 # FB High limit for MV

+Spk-000CDL-940:FB_LMN_HLIM_1 1Hz
 # FB Low limit for MV

+Spk-000CDL-940:FB_LMN_LLIM_1 1Hz
 # FB Proportional gain

+Spk-000CDL-940:FB_Gain_2 1Hz
 # FB Integration time

+Spk-000CDL-940:FB_TI_2 1Hz
 # FB Derivative action time

+Spk-000CDL-940:FB_TD_2 1Hz
 # FB Deadband

+Spk-000CDL-940:FB_DEADB_2 1Hz
 # FB High limit for MV

+Spk-000CDL-940:FB_LMN_HLIM_2 1Hz
 # FB Low limit for MV

+Spk-000CDL-940:FB_LMN_LLIM_2 1Hz
 # FB Proportional gain

+Spk-000CDL-940:FB_Gain_3 1Hz
 # FB Integration time

+Spk-000CDL-940:FB_TI_3 1Hz
 # FB Derivative action time

+Spk-000CDL-940:FB_TD_3 1Hz
 # FB Deadband

+Spk-000CDL-940:FB_DEADB_3 1Hz
 # FB High limit for MV

+Spk-000CDL-940:FB_LMN_HLIM_3 1Hz
 # FB Low limit for MV

+Spk-000CDL-940:FB_LMN_LLIM_3 1Hz
 ############################################################
-## Spk-000CDL:Cryo-PID-950
+## Spk-000CDL-950
 # Selected Measurement

+Spk-000CDL-950:SelectedPV
 # Manipulated Value

+Spk-000CDL-950:LMN
 # Manipulated Value P-Action

+Spk-000CDL-950:LMN_P
 # Manipulated Value I-Action

+Spk-000CDL-950:LMN_I
 # Manipulated Value D-Action

+Spk-000CDL-950:LMN_D
 # Actual PID Error/Difference

+Spk-000CDL-950:PID_DIF
 # PID Process Value

+Spk-000CDL-950:PV
 # PID Setpoint Value

+Spk-000CDL-950:MAN_SP
 # PV Name of the Process Value

+Spk-000CDL-950:ProcValueName
 # EGU of the Process Value

+Spk-000CDL-950:ProcValueEGU
 # 1st Select Measurement

+Spk-000CDL-950:Meas1_Name
 # 2nd Select Measurement

+Spk-000CDL-950:Meas2_Name
 # 3rd Select Measurement

+Spk-000CDL-950:Meas3_Name
 # Move Interlock

+Spk-000CDL-950:MoveInterlock
 # FB Setpoint from HMI (SP)

+Spk-000CDL-950:FB_Setpoint
 # FB Step value for Open/Close

+Spk-000CDL-950:FB_Step
 # Force Manipulated value (AO)

+Spk-000CDL-950:FB_Manipulated
 # FB Proportional gain

+Spk-000CDL-950:FB_Gain 1Hz
 # FB Integration time

+Spk-000CDL-950:FB_TI 1Hz
 # FB Derivative action time

+Spk-000CDL-950:FB_TD 1Hz
 # FB Deadband

+Spk-000CDL-950:FB_DEADB 1Hz
 # FB High limit for MV

+Spk-000CDL-950:FB_LMN_HLIM 1Hz
 # FB Low limit for MV

+Spk-000CDL-950:FB_LMN_LLIM 1Hz
 # FB Proportional gain

+Spk-000CDL-950:FB_Gain_1 1Hz
 # FB Integration time

+Spk-000CDL-950:FB_TI_1 1Hz
 # FB Derivative action time

+Spk-000CDL-950:FB_TD_1 1Hz
 # FB Deadband

+Spk-000CDL-950:FB_DEADB_1 1Hz
 # FB High limit for MV

+Spk-000CDL-950:FB_LMN_HLIM_1 1Hz
 # FB Low limit for MV

+Spk-000CDL-950:FB_LMN_LLIM_1 1Hz
 # FB Proportional gain

+Spk-000CDL-950:FB_Gain_2 1Hz
 # FB Integration time

+Spk-000CDL-950:FB_TI_2 1Hz
 # FB Derivative action time

+Spk-000CDL-950:FB_TD_2 1Hz
 # FB Deadband

+Spk-000CDL-950:FB_DEADB_2 1Hz
 # FB High limit for MV

+Spk-000CDL-950:FB_LMN_HLIM_2 1Hz
 # FB Low limit for MV

+Spk-000CDL-950:FB_LMN_LLIM_2 1Hz
 # FB Proportional gain

+Spk-000CDL-950:FB_Gain_3 1Hz
 # FB Integration time

+Spk-000CDL-950:FB_TI_3 1Hz
 # FB Derivative action time

+Spk-000CDL-950:FB_TD_3 1Hz
 # FB Deadband

+Spk-000CDL-950:FB_DEADB_3 1Hz
 # FB High limit for MV

+Spk-000CDL-950:FB_LMN_HLIM_3 1Hz
 # FB Low limit for MV

+Spk-000CDL-950:FB_LMN_LLIM_3 1Hz
 ############################################################
 ## Spk-000CDL:Cryo-PT-91
 # Pressure Value

+Spk-000CDL:Cryo-PT-91:MeasValue
 # RAW integer scaled

+Spk-000CDL:Cryo-PT-91:RAWValue
 # Pressure Underrange

+Spk-000CDL:Cryo-PT-91:Underrange
 # Pressure Overrange

+Spk-000CDL:Cryo-PT-91:Overrange
 # Pressure HIHI

+Spk-000CDL:Cryo-PT-91:HIHI
 # Pressure HI

+Spk-000CDL:Cryo-PT-91:HI
 # Pressure LO

+Spk-000CDL:Cryo-PT-91:LO
 # Pressure LOLO

+Spk-000CDL:Cryo-PT-91:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-PT-91:Param_Error
 # Module_Error

+Spk-000CDL:Cryo-PT-91:Module_Error
+# Cable_Error
+Spk-000CDL:Cryo-PT-91:Cable_Error
 ############################################################
 ## Spk-000CDL:Cryo-PT-92
 # Pressure Value

+Spk-000CDL:Cryo-PT-92:MeasValue
 # RAW integer scaled

+Spk-000CDL:Cryo-PT-92:RAWValue
 # Pressure Underrange

+Spk-000CDL:Cryo-PT-92:Underrange
 # Pressure Overrange

+Spk-000CDL:Cryo-PT-92:Overrange
 # Pressure HIHI

+Spk-000CDL:Cryo-PT-92:HIHI
 # Pressure HI

+Spk-000CDL:Cryo-PT-92:HI
 # Pressure LO

+Spk-000CDL:Cryo-PT-92:LO
 # Pressure LOLO

+Spk-000CDL:Cryo-PT-92:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-PT-92:Param_Error
 # Module_Error

+Spk-000CDL:Cryo-PT-92:Module_Error
+# Cable_Error
+Spk-000CDL:Cryo-PT-92:Cable_Error
 ############################################################
 ## Spk-000CDL:Cryo-PT-93
 # Pressure Value

+Spk-000CDL:Cryo-PT-93:MeasValue
 # RAW integer scaled

+Spk-000CDL:Cryo-PT-93:RAWValue
 # Pressure Underrange

+Spk-000CDL:Cryo-PT-93:Underrange
 # Pressure Overrange

+Spk-000CDL:Cryo-PT-93:Overrange
 # Pressure HIHI

+Spk-000CDL:Cryo-PT-93:HIHI
 # Pressure HI

+Spk-000CDL:Cryo-PT-93:HI
 # Pressure LO

+Spk-000CDL:Cryo-PT-93:LO
 # Pressure LOLO

+Spk-000CDL:Cryo-PT-93:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-PT-93:Param_Error
 # Module_Error

+Spk-000CDL:Cryo-PT-93:Module_Error
+# Cable_Error
+Spk-000CDL:Cryo-PT-93:Cable_Error
 ############################################################
 ## Spk-000CDL:Cryo-PT-94
 # Pressure Value

+Spk-000CDL:Cryo-PT-94:MeasValue
 # RAW integer scaled

+Spk-000CDL:Cryo-PT-94:RAWValue
 # Pressure Underrange

+Spk-000CDL:Cryo-PT-94:Underrange
 # Pressure Overrange

+Spk-000CDL:Cryo-PT-94:Overrange
 # Pressure HIHI

+Spk-000CDL:Cryo-PT-94:HIHI
 # Pressure HI

+Spk-000CDL:Cryo-PT-94:HI
 # Pressure LO

+Spk-000CDL:Cryo-PT-94:LO
 # Pressure LOLO

+Spk-000CDL:Cryo-PT-94:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-PT-94:Param_Error
 # Module_Error

+Spk-000CDL:Cryo-PT-94:Module_Error
+# Cable_Error
+Spk-000CDL:Cryo-PT-94:Cable_Error
 ############################################################
 ## Spk-000CDL:Cryo-PT-95
 # Pressure Value

+Spk-000CDL:Cryo-PT-95:MeasValue
 # RAW integer scaled

+Spk-000CDL:Cryo-PT-95:RAWValue
 # Pressure Underrange

+Spk-000CDL:Cryo-PT-95:Underrange
 # Pressure Overrange

+Spk-000CDL:Cryo-PT-95:Overrange
 # Pressure HIHI

+Spk-000CDL:Cryo-PT-95:HIHI
 # Pressure HI

+Spk-000CDL:Cryo-PT-95:HI
 # Pressure LO

+Spk-000CDL:Cryo-PT-95:LO
 # Pressure LOLO

+Spk-000CDL:Cryo-PT-95:LOLO
 # Parameter_Error

+Spk-000CDL:Cryo-PT-95:Param_Error
 # Module_Error

+Spk-000CDL:Cryo-PT-95:Module_Error

"""

# %%
as_228_update_pvs = []

for line in input_text.splitlines():
    if line.startswith("+S"):
        as_228_update_pvs.append(line.split("+")[1].split()[0])

# %%
as_228_update_pvs
# Out:
# ['Spk-000CDL:Cryo-PLC-010:ModVersionR',
#  'Spk-000CDL:Cryo-PLC-010:ModbusConnectedR',
#  'Spk-000CDL:Cryo-PLC-010:S7ConnectedR',
#  'Spk-000CDL:Cryo-PLC-010:PLCAddr-RB',
#  'Spk-000CDL:Cryo-PLC-010:ConnectedR',
#  'Spk-000CDL:Cryo-PLC-010:PLCHashCorrectR',
#  'Spk-000CDL:Cryo-PLC-010:AliveR',
#  'Spk-000CDL:Cryo-PLC-010:CommsHashToPLC',
#  'Spk-000CDL:Cryo-PLC-010:CommsHashFromPLCR',
#  'Spk-000CDL:Cryo-PLC-010:PayloadSizeR',
#  'Spk-000CDL:Cryo-PLC-010:PayloadSizeFromPLCR',
#  'Spk-000CDL:Cryo-PLC-010:PayloadSizeCorrectR',
#  'Spk-000CDL:Cryo-PLC-010:ParametersFrozen',
#  'Spk-000CDL:Cryo-PLC-010:Cmd_AckAlarm',
#  'Spk-000CDL:Cryo-PLC-010:Cmd_ParamFreeze_OFF',
#  'Spk-000CDL:SC-FSM-400:CavityVac1',
#  'Spk-000CDL:SC-FSM-400:CavityVac2',
#  'Spk-000CDL:SC-FSM-400:CavityVac3',
#  'Spk-000CDL:SC-FSM-400:CavityVac4',
#  'Spk-000CDL:SC-FSM-400:CMGaugeIsoVac1',
#  'Spk-000CDL:SC-FSM-400:CMGaugeIsoVac2',
#  'Spk-000CDL::VacOK1',
#  'Spk-000CDL::VacOK2',
#  'Spk-000CDL::CDS_Cryo_Ready',
# ...

# %%
for pv in as_228_update_pvs:
    archiver_linac_tn.update_pv(pv, 1.0)

# %% [markdown]
# ### PV replacement

# %%
old_pvs_input_text = """

-############################################################
-## Spk-000CDL:Cryo-PID-91
-# Selected Measurement
-Spk-000CDL:Cryo-PID-91:SelectedPV 4Hz
-# Manipulated Value
-Spk-000CDL:Cryo-PID-91:LMN 4Hz
-# Manipulated Value P-Action
-Spk-000CDL:Cryo-PID-91:LMN_P 4Hz
-# Manipulated Value I-Action
-Spk-000CDL:Cryo-PID-91:LMN_I 4Hz
-# Manipulated Value D-Action
-Spk-000CDL:Cryo-PID-91:LMN_D 4Hz
-# Actual PID Error/Difference
-Spk-000CDL:Cryo-PID-91:PID_DIF 4Hz
-# PID Process Value
-Spk-000CDL:Cryo-PID-91:PV 4Hz
-# PID Setpoint Value
-Spk-000CDL:Cryo-PID-91:MAN_SP 4Hz
-# PV Name of the Process Value
-Spk-000CDL:Cryo-PID-91:ProcValueName 4Hz
-# EGU of the Process Value
-Spk-000CDL:Cryo-PID-91:ProcValueEGU 4Hz
-# 1st Select Measurement
-Spk-000CDL:Cryo-PID-91:Meas1_Name 4Hz
-# 2nd Select Measurement
-Spk-000CDL:Cryo-PID-91:Meas2_Name 4Hz
-# 3rd Select Measurement
-Spk-000CDL:Cryo-PID-91:Meas3_Name 4Hz
-# Move Interlock
-Spk-000CDL:Cryo-PID-91:MoveInterlock 4Hz
-# FB Setpoint from HMI (SP)
-Spk-000CDL:Cryo-PID-91:FB_Setpoint 4Hz
-# FB Step value for Open/Close
-Spk-000CDL:Cryo-PID-91:FB_Step 4Hz
-# Force Manipulated value (AO)
-Spk-000CDL:Cryo-PID-91:FB_Manipulated 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-91:FB_Gain 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-91:FB_TI 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-91:FB_TD 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-91:FB_DEADB 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_HLIM 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_LLIM 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-91:FB_Gain_1 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-91:FB_TI_1 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-91:FB_TD_1 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-91:FB_DEADB_1 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_HLIM_1 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_LLIM_1 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-91:FB_Gain_2 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-91:FB_TI_2 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-91:FB_TD_2 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-91:FB_DEADB_2 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_HLIM_2 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_LLIM_2 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-91:FB_Gain_3 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-91:FB_TI_3 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-91:FB_TD_3 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-91:FB_DEADB_3 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_HLIM_3 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-91:FB_LMN_LLIM_3 4Hz
-############################################################
-## Spk-000CDL:Cryo-PID-910
-# Selected Measurement
-Spk-000CDL:Cryo-PID-910:SelectedPV 4Hz
-# Manipulated Value
-Spk-000CDL:Cryo-PID-910:LMN 4Hz
-# Manipulated Value P-Action
-Spk-000CDL:Cryo-PID-910:LMN_P 4Hz
-# Manipulated Value I-Action
-Spk-000CDL:Cryo-PID-910:LMN_I 4Hz
-# Manipulated Value D-Action
-Spk-000CDL:Cryo-PID-910:LMN_D 4Hz
-# Actual PID Error/Difference
-Spk-000CDL:Cryo-PID-910:PID_DIF 4Hz
-# PID Process Value
-Spk-000CDL:Cryo-PID-910:PV 4Hz
-# PID Setpoint Value
-Spk-000CDL:Cryo-PID-910:MAN_SP 4Hz
-# PV Name of the Process Value
-Spk-000CDL:Cryo-PID-910:ProcValueName 4Hz
-# EGU of the Process Value
-Spk-000CDL:Cryo-PID-910:ProcValueEGU 4Hz
-# 1st Select Measurement
-Spk-000CDL:Cryo-PID-910:Meas1_Name 4Hz
-# 2nd Select Measurement
-Spk-000CDL:Cryo-PID-910:Meas2_Name 4Hz
-# 3rd Select Measurement
-Spk-000CDL:Cryo-PID-910:Meas3_Name 4Hz
-# Move Interlock
-Spk-000CDL:Cryo-PID-910:MoveInterlock 4Hz
-# FB Setpoint from HMI (SP)
-Spk-000CDL:Cryo-PID-910:FB_Setpoint 4Hz
-# FB Step value for Open/Close
-Spk-000CDL:Cryo-PID-910:FB_Step 4Hz
-# Force Manipulated value (AO)
-Spk-000CDL:Cryo-PID-910:FB_Manipulated 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-910:FB_Gain 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-910:FB_TI 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-910:FB_TD 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-910:FB_DEADB 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_HLIM 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_LLIM 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-910:FB_Gain_1 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-910:FB_TI_1 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-910:FB_TD_1 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-910:FB_DEADB_1 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_HLIM_1 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_LLIM_1 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-910:FB_Gain_2 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-910:FB_TI_2 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-910:FB_TD_2 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-910:FB_DEADB_2 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_HLIM_2 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_LLIM_2 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-910:FB_Gain_3 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-910:FB_TI_3 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-910:FB_TD_3 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-910:FB_DEADB_3 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_HLIM_3 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-910:FB_LMN_LLIM_3 4Hz
-############################################################
-## Spk-000CDL:Cryo-PID-92
-# Selected Measurement
-Spk-000CDL:Cryo-PID-92:SelectedPV 4Hz
-# Manipulated Value
-Spk-000CDL:Cryo-PID-92:LMN 4Hz
-# Manipulated Value P-Action
-Spk-000CDL:Cryo-PID-92:LMN_P 4Hz
-# Manipulated Value I-Action
-Spk-000CDL:Cryo-PID-92:LMN_I 4Hz
-# Manipulated Value D-Action
-Spk-000CDL:Cryo-PID-92:LMN_D 4Hz
-# Actual PID Error/Difference
-Spk-000CDL:Cryo-PID-92:PID_DIF 4Hz
-# PID Process Value
-Spk-000CDL:Cryo-PID-92:PV 4Hz
-# PID Setpoint Value
-Spk-000CDL:Cryo-PID-92:MAN_SP 4Hz
-# PV Name of the Process Value
-Spk-000CDL:Cryo-PID-92:ProcValueName 4Hz
-# EGU of the Process Value
-Spk-000CDL:Cryo-PID-92:ProcValueEGU 4Hz
-# 1st Select Measurement
-Spk-000CDL:Cryo-PID-92:Meas1_Name 4Hz
-# 2nd Select Measurement
-Spk-000CDL:Cryo-PID-92:Meas2_Name 4Hz
-# 3rd Select Measurement
-Spk-000CDL:Cryo-PID-92:Meas3_Name 4Hz
-# Move Interlock
-Spk-000CDL:Cryo-PID-92:MoveInterlock 4Hz
-# FB Setpoint from HMI (SP)
-Spk-000CDL:Cryo-PID-92:FB_Setpoint 4Hz
-# FB Step value for Open/Close
-Spk-000CDL:Cryo-PID-92:FB_Step 4Hz
-# Force Manipulated value (AO)
-Spk-000CDL:Cryo-PID-92:FB_Manipulated 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-92:FB_Gain 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-92:FB_TI 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-92:FB_TD 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-92:FB_DEADB 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_HLIM 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_LLIM 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-92:FB_Gain_1 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-92:FB_TI_1 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-92:FB_TD_1 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-92:FB_DEADB_1 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_HLIM_1 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_LLIM_1 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-92:FB_Gain_2 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-92:FB_TI_2 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-92:FB_TD_2 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-92:FB_DEADB_2 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_HLIM_2 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_LLIM_2 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-92:FB_Gain_3 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-92:FB_TI_3 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-92:FB_TD_3 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-92:FB_DEADB_3 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_HLIM_3 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-92:FB_LMN_LLIM_3 4Hz
-############################################################
-## Spk-000CDL:Cryo-PID-920
-# Selected Measurement
-Spk-000CDL:Cryo-PID-920:SelectedPV 4Hz
-# Manipulated Value
-Spk-000CDL:Cryo-PID-920:LMN 4Hz
-# Manipulated Value P-Action
-Spk-000CDL:Cryo-PID-920:LMN_P 4Hz
-# Manipulated Value I-Action
-Spk-000CDL:Cryo-PID-920:LMN_I 4Hz
-# Manipulated Value D-Action
-Spk-000CDL:Cryo-PID-920:LMN_D 4Hz
-# Actual PID Error/Difference
-Spk-000CDL:Cryo-PID-920:PID_DIF 4Hz
-# PID Process Value
-Spk-000CDL:Cryo-PID-920:PV 4Hz
-# PID Setpoint Value
-Spk-000CDL:Cryo-PID-920:MAN_SP 4Hz
-# PV Name of the Process Value
-Spk-000CDL:Cryo-PID-920:ProcValueName 4Hz
-# EGU of the Process Value
-Spk-000CDL:Cryo-PID-920:ProcValueEGU 4Hz
-# 1st Select Measurement
-Spk-000CDL:Cryo-PID-920:Meas1_Name 4Hz
-# 2nd Select Measurement
-Spk-000CDL:Cryo-PID-920:Meas2_Name 4Hz
-# 3rd Select Measurement
-Spk-000CDL:Cryo-PID-920:Meas3_Name 4Hz
-# Move Interlock
-Spk-000CDL:Cryo-PID-920:MoveInterlock 4Hz
-# FB Setpoint from HMI (SP)
-Spk-000CDL:Cryo-PID-920:FB_Setpoint 4Hz
-# FB Step value for Open/Close
-Spk-000CDL:Cryo-PID-920:FB_Step 4Hz
-# Force Manipulated value (AO)
-Spk-000CDL:Cryo-PID-920:FB_Manipulated 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-920:FB_Gain 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-920:FB_TI 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-920:FB_TD 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-920:FB_DEADB 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_HLIM 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_LLIM 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-920:FB_Gain_1 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-920:FB_TI_1 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-920:FB_TD_1 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-920:FB_DEADB_1 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_HLIM_1 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_LLIM_1 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-920:FB_Gain_2 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-920:FB_TI_2 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-920:FB_TD_2 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-920:FB_DEADB_2 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_HLIM_2 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_LLIM_2 4Hz
-# FB Proportional gain
-Spk-000CDL:Cryo-PID-920:FB_Gain_3 4Hz
-# FB Integration time
-Spk-000CDL:Cryo-PID-920:FB_TI_3 4Hz
-# FB Derivative action time
-Spk-000CDL:Cryo-PID-920:FB_TD_3 4Hz
-# FB Deadband
-Spk-000CDL:Cryo-PID-920:FB_DEADB_3 4Hz
-# FB High limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_HLIM_3 4Hz
-# FB Low limit for MV
-Spk-000CDL:Cryo-PID-920:FB_LMN_LLIM_3 4Hz
"""

# %%
new_pvs_text = """
-############################################################
-## Spk-000CDL:SC-PID-91
-# Selected Measurement
-Spk-000CDL:SC-PID-91:SelectedPV 
-# Manipulated Value
-Spk-000CDL:SC-PID-91:LMN 
-# Manipulated Value P-Action
-Spk-000CDL:SC-PID-91:LMN_P 
-# Manipulated Value I-Action
-Spk-000CDL:SC-PID-91:LMN_I 
-# Manipulated Value D-Action
-Spk-000CDL:SC-PID-91:LMN_D 
-# Actual PID Error/Difference
-Spk-000CDL:SC-PID-91:PID_DIF 
-# PID Process Value
-Spk-000CDL:SC-PID-91:PV 
-# PID Setpoint Value
-Spk-000CDL:SC-PID-91:MAN_SP 
-# PV Name of the Process Value
-Spk-000CDL:SC-PID-91:ProcValueName 
-# EGU of the Process Value
-Spk-000CDL:SC-PID-91:ProcValueEGU 
-# 1st Select Measurement
-Spk-000CDL:SC-PID-91:Meas1_Name 
-# 2nd Select Measurement
-Spk-000CDL:SC-PID-91:Meas2_Name 
-# 3rd Select Measurement
-Spk-000CDL:SC-PID-91:Meas3_Name 
-# Move Interlock
-Spk-000CDL:SC-PID-91:MoveInterlock 
-# FB Setpoint from HMI (SP)
-Spk-000CDL:SC-PID-91:FB_Setpoint 
-# FB Step value for Open/Close
-Spk-000CDL:SC-PID-91:FB_Step 
-# Force Manipulated value (AO)
-Spk-000CDL:SC-PID-91:FB_Manipulated 
-# FB Proportional gain
-Spk-000CDL:SC-PID-91:FB_Gain 
-# FB Integration time
-Spk-000CDL:SC-PID-91:FB_TI 
-# FB Derivative action time
-Spk-000CDL:SC-PID-91:FB_TD 
-# FB Deadband
-Spk-000CDL:SC-PID-91:FB_DEADB 
-# FB High limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_HLIM 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_LLIM 
-# FB Proportional gain
-Spk-000CDL:SC-PID-91:FB_Gain_1 
-# FB Integration time
-Spk-000CDL:SC-PID-91:FB_TI_1 
-# FB Derivative action time
-Spk-000CDL:SC-PID-91:FB_TD_1 
-# FB Deadband
-Spk-000CDL:SC-PID-91:FB_DEADB_1 
-# FB High limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_HLIM_1 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_LLIM_1 
-# FB Proportional gain
-Spk-000CDL:SC-PID-91:FB_Gain_2 
-# FB Integration time
-Spk-000CDL:SC-PID-91:FB_TI_2 
-# FB Derivative action time
-Spk-000CDL:SC-PID-91:FB_TD_2 
-# FB Deadband
-Spk-000CDL:SC-PID-91:FB_DEADB_2 
-# FB High limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_HLIM_2 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_LLIM_2 
-# FB Proportional gain
-Spk-000CDL:SC-PID-91:FB_Gain_3 
-# FB Integration time
-Spk-000CDL:SC-PID-91:FB_TI_3 
-# FB Derivative action time
-Spk-000CDL:SC-PID-91:FB_TD_3 
-# FB Deadband
-Spk-000CDL:SC-PID-91:FB_DEADB_3 
-# FB High limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_HLIM_3 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-91:FB_LMN_LLIM_3 
-############################################################
-## Spk-000CDL:SC-PID-910
-# Selected Measurement
-Spk-000CDL:SC-PID-910:SelectedPV 
-# Manipulated Value
-Spk-000CDL:SC-PID-910:LMN 
-# Manipulated Value P-Action
-Spk-000CDL:SC-PID-910:LMN_P 
-# Manipulated Value I-Action
-Spk-000CDL:SC-PID-910:LMN_I 
-# Manipulated Value D-Action
-Spk-000CDL:SC-PID-910:LMN_D 
-# Actual PID Error/Difference
-Spk-000CDL:SC-PID-910:PID_DIF 
-# PID Process Value
-Spk-000CDL:SC-PID-910:PV 
-# PID Setpoint Value
-Spk-000CDL:SC-PID-910:MAN_SP 
-# PV Name of the Process Value
-Spk-000CDL:SC-PID-910:ProcValueName 
-# EGU of the Process Value
-Spk-000CDL:SC-PID-910:ProcValueEGU 
-# 1st Select Measurement
-Spk-000CDL:SC-PID-910:Meas1_Name 
-# 2nd Select Measurement
-Spk-000CDL:SC-PID-910:Meas2_Name 
-# 3rd Select Measurement
-Spk-000CDL:SC-PID-910:Meas3_Name 
-# Move Interlock
-Spk-000CDL:SC-PID-910:MoveInterlock 
-# FB Setpoint from HMI (SP)
-Spk-000CDL:SC-PID-910:FB_Setpoint 
-# FB Step value for Open/Close
-Spk-000CDL:SC-PID-910:FB_Step 
-# Force Manipulated value (AO)
-Spk-000CDL:SC-PID-910:FB_Manipulated 
-# FB Proportional gain
-Spk-000CDL:SC-PID-910:FB_Gain 
-# FB Integration time
-Spk-000CDL:SC-PID-910:FB_TI 
-# FB Derivative action time
-Spk-000CDL:SC-PID-910:FB_TD 
-# FB Deadband
-Spk-000CDL:SC-PID-910:FB_DEADB 
-# FB High limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_HLIM 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_LLIM 
-# FB Proportional gain
-Spk-000CDL:SC-PID-910:FB_Gain_1 
-# FB Integration time
-Spk-000CDL:SC-PID-910:FB_TI_1 
-# FB Derivative action time
-Spk-000CDL:SC-PID-910:FB_TD_1 
-# FB Deadband
-Spk-000CDL:SC-PID-910:FB_DEADB_1 
-# FB High limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_HLIM_1 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_LLIM_1 
-# FB Proportional gain
-Spk-000CDL:SC-PID-910:FB_Gain_2 
-# FB Integration time
-Spk-000CDL:SC-PID-910:FB_TI_2 
-# FB Derivative action time
-Spk-000CDL:SC-PID-910:FB_TD_2 
-# FB Deadband
-Spk-000CDL:SC-PID-910:FB_DEADB_2 
-# FB High limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_HLIM_2 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_LLIM_2 
-# FB Proportional gain
-Spk-000CDL:SC-PID-910:FB_Gain_3 
-# FB Integration time
-Spk-000CDL:SC-PID-910:FB_TI_3 
-# FB Derivative action time
-Spk-000CDL:SC-PID-910:FB_TD_3 
-# FB Deadband
-Spk-000CDL:SC-PID-910:FB_DEADB_3 
-# FB High limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_HLIM_3 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-910:FB_LMN_LLIM_3 
-############################################################
-## Spk-000CDL:SC-PID-92
-# Selected Measurement
-Spk-000CDL:SC-PID-92:SelectedPV 
-# Manipulated Value
-Spk-000CDL:SC-PID-92:LMN 
-# Manipulated Value P-Action
-Spk-000CDL:SC-PID-92:LMN_P 
-# Manipulated Value I-Action
-Spk-000CDL:SC-PID-92:LMN_I 
-# Manipulated Value D-Action
-Spk-000CDL:SC-PID-92:LMN_D 
-# Actual PID Error/Difference
-Spk-000CDL:SC-PID-92:PID_DIF 
-# PID Process Value
-Spk-000CDL:SC-PID-92:PV 
-# PID Setpoint Value
-Spk-000CDL:SC-PID-92:MAN_SP 
-# PV Name of the Process Value
-Spk-000CDL:SC-PID-92:ProcValueName 
-# EGU of the Process Value
-Spk-000CDL:SC-PID-92:ProcValueEGU 
-# 1st Select Measurement
-Spk-000CDL:SC-PID-92:Meas1_Name 
-# 2nd Select Measurement
-Spk-000CDL:SC-PID-92:Meas2_Name 
-# 3rd Select Measurement
-Spk-000CDL:SC-PID-92:Meas3_Name 
-# Move Interlock
-Spk-000CDL:SC-PID-92:MoveInterlock 
-# FB Setpoint from HMI (SP)
-Spk-000CDL:SC-PID-92:FB_Setpoint 
-# FB Step value for Open/Close
-Spk-000CDL:SC-PID-92:FB_Step 
-# Force Manipulated value (AO)
-Spk-000CDL:SC-PID-92:FB_Manipulated 
-# FB Proportional gain
-Spk-000CDL:SC-PID-92:FB_Gain 
-# FB Integration time
-Spk-000CDL:SC-PID-92:FB_TI 
-# FB Derivative action time
-Spk-000CDL:SC-PID-92:FB_TD 
-# FB Deadband
-Spk-000CDL:SC-PID-92:FB_DEADB 
-# FB High limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_HLIM 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_LLIM 
-# FB Proportional gain
-Spk-000CDL:SC-PID-92:FB_Gain_1 
-# FB Integration time
-Spk-000CDL:SC-PID-92:FB_TI_1 
-# FB Derivative action time
-Spk-000CDL:SC-PID-92:FB_TD_1 
-# FB Deadband
-Spk-000CDL:SC-PID-92:FB_DEADB_1 
-# FB High limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_HLIM_1 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_LLIM_1 
-# FB Proportional gain
-Spk-000CDL:SC-PID-92:FB_Gain_2 
-# FB Integration time
-Spk-000CDL:SC-PID-92:FB_TI_2 
-# FB Derivative action time
-Spk-000CDL:SC-PID-92:FB_TD_2 
-# FB Deadband
-Spk-000CDL:SC-PID-92:FB_DEADB_2 
-# FB High limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_HLIM_2 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_LLIM_2 
-# FB Proportional gain
-Spk-000CDL:SC-PID-92:FB_Gain_3 
-# FB Integration time
-Spk-000CDL:SC-PID-92:FB_TI_3 
-# FB Derivative action time
-Spk-000CDL:SC-PID-92:FB_TD_3 
-# FB Deadband
-Spk-000CDL:SC-PID-92:FB_DEADB_3 
-# FB High limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_HLIM_3 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-92:FB_LMN_LLIM_3 
-############################################################
-## Spk-000CDL:SC-PID-920
-# Selected Measurement
-Spk-000CDL:SC-PID-920:SelectedPV 
-# Manipulated Value
-Spk-000CDL:SC-PID-920:LMN 
-# Manipulated Value P-Action
-Spk-000CDL:SC-PID-920:LMN_P 
-# Manipulated Value I-Action
-Spk-000CDL:SC-PID-920:LMN_I 
-# Manipulated Value D-Action
-Spk-000CDL:SC-PID-920:LMN_D 
-# Actual PID Error/Difference
-Spk-000CDL:SC-PID-920:PID_DIF 
-# PID Process Value
-Spk-000CDL:SC-PID-920:PV 
-# PID Setpoint Value
-Spk-000CDL:SC-PID-920:MAN_SP 
-# PV Name of the Process Value
-Spk-000CDL:SC-PID-920:ProcValueName 
-# EGU of the Process Value
-Spk-000CDL:SC-PID-920:ProcValueEGU 
-# 1st Select Measurement
-Spk-000CDL:SC-PID-920:Meas1_Name 
-# 2nd Select Measurement
-Spk-000CDL:SC-PID-920:Meas2_Name 
-# 3rd Select Measurement
-Spk-000CDL:SC-PID-920:Meas3_Name 
-# Move Interlock
-Spk-000CDL:SC-PID-920:MoveInterlock 
-# FB Setpoint from HMI (SP)
-Spk-000CDL:SC-PID-920:FB_Setpoint 
-# FB Step value for Open/Close
-Spk-000CDL:SC-PID-920:FB_Step 
-# Force Manipulated value (AO)
-Spk-000CDL:SC-PID-920:FB_Manipulated 
-# FB Proportional gain
-Spk-000CDL:SC-PID-920:FB_Gain 
-# FB Integration time
-Spk-000CDL:SC-PID-920:FB_TI 
-# FB Derivative action time
-Spk-000CDL:SC-PID-920:FB_TD 
-# FB Deadband
-Spk-000CDL:SC-PID-920:FB_DEADB 
-# FB High limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_HLIM 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_LLIM 
-# FB Proportional gain
-Spk-000CDL:SC-PID-920:FB_Gain_1 
-# FB Integration time
-Spk-000CDL:SC-PID-920:FB_TI_1 
-# FB Derivative action time
-Spk-000CDL:SC-PID-920:FB_TD_1 
-# FB Deadband
-Spk-000CDL:SC-PID-920:FB_DEADB_1 
-# FB High limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_HLIM_1 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_LLIM_1 
-# FB Proportional gain
-Spk-000CDL:SC-PID-920:FB_Gain_2 
-# FB Integration time
-Spk-000CDL:SC-PID-920:FB_TI_2 
-# FB Derivative action time
-Spk-000CDL:SC-PID-920:FB_TD_2 
-# FB Deadband
-Spk-000CDL:SC-PID-920:FB_DEADB_2 
-# FB High limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_HLIM_2 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_LLIM_2 
-# FB Proportional gain
-Spk-000CDL:SC-PID-920:FB_Gain_3 
-# FB Integration time
-Spk-000CDL:SC-PID-920:FB_TI_3 
-# FB Derivative action time
-Spk-000CDL:SC-PID-920:FB_TD_3 
-# FB Deadband
-Spk-000CDL:SC-PID-920:FB_DEADB_3 
-# FB High limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_HLIM_3 
-# FB Low limit for MV
-Spk-000CDL:SC-PID-920:FB_LMN_LLIM_3 
"""

# %%
as_228_old_pvs = []
for line in old_pvs_input_text.splitlines():
    if line.startswith("-S"):
        as_228_old_pvs.append(line.removeprefix("-").split()[0])
        
as_228_new_pvs = []
for line in new_pvs_text.splitlines():
    if line.startswith("-S"):
        as_228_new_pvs.append(line.removeprefix("-").split()[0])

# %%
len(as_228_new_pvs)
# Out:
# 164

# %%
len(as_228_old_pvs)
# Out:
# 164

# %%
as_228_pv_comb = list(zip(as_228_old_pvs, as_228_new_pvs))

# %%
as_228_pv_comb
# Out:
# [('Spk-000CDL:Cryo-PID-91:SelectedPV', 'Spk-000CDL:SC-PID-91:SelectedPV'),
#  ('Spk-000CDL:Cryo-PID-91:LMN', 'Spk-000CDL:SC-PID-91:LMN'),
#  ('Spk-000CDL:Cryo-PID-91:LMN_P', 'Spk-000CDL:SC-PID-91:LMN_P'),
#  ('Spk-000CDL:Cryo-PID-91:LMN_I', 'Spk-000CDL:SC-PID-91:LMN_I'),
#  ('Spk-000CDL:Cryo-PID-91:LMN_D', 'Spk-000CDL:SC-PID-91:LMN_D'),
#  ('Spk-000CDL:Cryo-PID-91:PID_DIF', 'Spk-000CDL:SC-PID-91:PID_DIF'),
#  ('Spk-000CDL:Cryo-PID-91:PV', 'Spk-000CDL:SC-PID-91:PV'),
#  ('Spk-000CDL:Cryo-PID-91:MAN_SP', 'Spk-000CDL:SC-PID-91:MAN_SP'),
#  ('Spk-000CDL:Cryo-PID-91:ProcValueName',
#   'Spk-000CDL:SC-PID-91:ProcValueName'),
#  ('Spk-000CDL:Cryo-PID-91:ProcValueEGU', 'Spk-000CDL:SC-PID-91:ProcValueEGU'),
#  ('Spk-000CDL:Cryo-PID-91:Meas1_Name', 'Spk-000CDL:SC-PID-91:Meas1_Name'),
#  ('Spk-000CDL:Cryo-PID-91:Meas2_Name', 'Spk-000CDL:SC-PID-91:Meas2_Name'),
#  ('Spk-000CDL:Cryo-PID-91:Meas3_Name', 'Spk-000CDL:SC-PID-91:Meas3_Name'),
#  ('Spk-000CDL:Cryo-PID-91:MoveInterlock',
# ...

# %%
fake_archiver = ArchiverAppliance()

# %%
from epicsarchiver.mgmt.archiver_mgmt_operations import Storage

# %%
for combo in as_228_pv_comb:
    fake_archiver.pause_pv(combo[0])
    fake_archiver.pause_pv(combo[1])
    fake_archiver.rename_and_append(combo[0], combo[1], Storage.MTS)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/git/ics-software/archiver-appliance/mgmt_operations/.venv/lib/python3.13/site-packages/urllib3/connection.py:199, in HTTPConnection._new_conn(self)
#     198 try:
# --> 199     sock = connection.create_connection(
#     200         (self._dns_host, self.port),
#     201         self.timeout,
#     202         source_address=self.source_address,
#     203         socket_options=self.socket_options,
#     204     )
#     205 except socket.gaierror as e:
#
# File ~/git/ics-software/archiver-appliance/mgmt_operations/.venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# ...

# %%
for combo in as_228_pv_comb:
    archiver_linac_tn.pause_pv(combo[0])
    archiver_linac_tn.pause_pv(combo[1])
    archiver_linac_tn.rename_and_append(combo[0], combo[1], Storage.MTS)
# Out:
# [09:55:55] ERROR    PV Spk-000CDL:SC-PID-91:Meas1_Name isn't paused. Skipping.      ]8;id=412173;file:///Users/skybrewer/git/ics-software/archiver-appliance/mgmt_operations/.venv/lib/python3.13/site-packages/epicsarchiver/mgmt/archiver_mgmt_operations.py\archiver_mgmt_operations.py]8;;\:]8;id=887261;file:///Users/skybrewer/git/ics-software/archiver-appliance/mgmt_operations/.venv/lib/python3.13/site-packages/epicsarchiver/mgmt/archiver_mgmt_operations.py#275\275]8;;\
#            ERROR    PV Spk-000CDL:SC-PID-91:Meas2_Name isn't paused. Skipping.      ]8;id=615864;file:///Users/skybrewer/git/ics-software/archiver-appliance/mgmt_operations/.venv/lib/python3.13/site-packages/epicsarchiver/mgmt/archiver_mgmt_operations.py\archiver_mgmt_operations.py]8;;\:]8;id=778280;file:///Users/skybrewer/git/ics-software/archiver-appliance/mgmt_operations/.venv/lib/python3.13/site-packages/epicsarchiver/mgmt/archiver_mgmt_operations.py#275\275]8;;\
# ...

# %%
for pv in as_228_new_pvs:
    archiver_linac_tn.resume_pv(pv)
