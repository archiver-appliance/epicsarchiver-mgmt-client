# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    filename="logs/mgmt_operations.as_254.log",
    encoding="utf-8",
)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
ioc_pvs = [
    
"CrS-CMS:Cryo-CV-42320:FlowSP",
"CrS-CMS:Cryo-CV-42320:OpMode_Manual",
"CrS-CMS:Cryo-CV-42320:P_ForcePosition",
"CrS-CMS:Cryo-CV-42320:RAWValue",
"CrS-CMS:Cryo-CV-42320:ST_Closed_Raw",
"CrS-CMS:Cryo-CV-42320:ST_Opened_Raw",
"CrS-CMS:Cryo-CV-42320:ActualFlow",
"CrS-CMS:Cryo-CV-42320:FlowMV",
"CrS-CMS:Cryo-CV-42320:MoveInterlock",
"CrS-CMS:Cryo-CV-42320:OpMode_Auto",
"CrS-CMS:Cryo-CV-42320:OpMode_Forced",
"CrS-CMS:Cryo-CV-42320:P_Manipulated",
"CrS-CMS:Cryo-CV-42320:P_RampDNRANGE",
"CrS-CMS:Cryo-CV-42320:P_RampDNTIME",
"CrS-CMS:Cryo-CV-42320:P_RampUPRANGE",
"CrS-CMS:Cryo-CV-42320:P_RampUPTIME",
"CrS-CMS:Cryo-CV-42320:P_Setpoint",
"CrS-CMS:Cryo-CV-42320:ValveMV",
"CrS-CMS:Cryo-CV-42320:ValvePosition",
"CrS-CMS:Cryo-CV-42320:ValveSP",
"CrS-CMS:Cryo-CV-42320:Cmd_Auto",
"CrS-CMS:Cryo-CV-42320:Cmd_Force",
"CrS-CMS:Cryo-CV-42320:Cmd_ForceValInp",
"CrS-CMS:Cryo-CV-42320:Cmd_RampOFF",
"CrS-CMS:Cryo-CV-42320:Cmd_AckAlarm",
"CrS-CMS:Cryo-CV-42320:Cmd_ForceValOut",
"CrS-CMS:Cryo-CV-42320:Cmd_Manual",
"CrS-CMS:Cryo-CV-42320:Cmd_RampON",

]

# %%
from epicsarchiver import ArchiverAppliance
archiver_linac = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %%
for pv in ioc_pvs:
    archiver_linac.pause_pv(pv)
