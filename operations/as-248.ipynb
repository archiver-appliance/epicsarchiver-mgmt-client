# %%
import logging

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    filename="logs/mgmt_operations.as_248.log",
    encoding="utf-8",
)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
pvs = [
"TgtGDS:ODH-AreaE-115:BPCS_SpState_Test",
"TgtGDS:ODH-AreaE-115:BPCS_SpState_Act",
"TgtGDS:ODH-AreaE-115:BPCS_H2Above25_Test",
"TgtGDS:ODH-AreaE-115:BPCS_H2Above25_Act",
"TgtGDS:ODH-AreaE-115:BPCS_H2Above10_Test",
"TgtGDS:ODH-AreaE-115:BPCS_H2Above10_Act",
"TgtGDS:ODH-Area-150:BPCS_SpState_Test",
"TgtGDS:ODH-Area-150:BPCS_SpState_Act",
"TgtGDS:ODH-Area-150:BPCS_H2Above25_Test",
"TgtGDS:ODH-Area-150:BPCS_H2Above25_Act",
"TgtGDS:ODH-Area-150:BPCS_H2Above10_Test",
"TgtGDS:ODH-Area-150:BPCS_H2Above10_Act",
"TgtGDS::BPCS_ClsPerm2_Test",
"TgtGDS::BPCS_ClsPerm2_Inact",
"TgtGDS::BPCS_ClsPerm1_Test",
"TgtGDS::BPCS_ClsPerm1_Inact",
]

# %%
from epicsarchiver import ArchiverAppliance

# %%
archiver_linac = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %%
for pv in pvs:
    archiver_linac.pause_pv(pv)
