# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    filename="logs/mgmt_operations.as_257.log",
    encoding="utf-8",
)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
pvs = ["TD-M:Ctrl-SCE-1:Dbuf-Sts-I", "TD-M:Ctrl-SCE-1:ScTable-Sts-I"]

# %%
from epicsarchiver import ArchiverAppliance
archiver_linac = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %%
archiver_linac.get_pv_status(pvs)
# Out:
# [{'lastRotateLogs': 'Never',
#   'appliance': 'archiver-linac-10',
#   'pvName': 'TD-M:Ctrl-SCE-1:Dbuf-Sts-I',
#   'pvNameOnly': 'TD-M:Ctrl-SCE-1:Dbuf-Sts-I',
#   'connectionState': 'true',
#   'lastEvent': 'Nov/29/2024 11:11:57 +01:00',
#   'samplingPeriod': '0.07',
#   'isMonitored': 'true',
#   'connectionLastRestablished': 'Feb/28/2025 13:47:23 +01:00',
#   'connectionFirstEstablished': 'Aug/27/2024 10:41:45 +02:00',
#   'connectionLossRegainCount': '10',
#   'status': 'Being archived'}]

# %%
appliance= 'archiver-linac-10'

# %%
for pv in pvs:
    archiver_linac.pause_pv(pv)

# %%
for pv in pvs:
    archiver_linac.delete_pv(pv)

# %%
for pv in pvs:
    archiver_linac.archive_pv(f"pva://{pv}", appliance=appliance)

# %%
for pv in pvs:
    pv_status = archiver_linac.get_pv_status(pv)
    LOG.info(pv_status)
