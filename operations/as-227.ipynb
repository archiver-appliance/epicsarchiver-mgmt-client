# %% [markdown]
# # Mgmt Operations

# %% [markdown]
# ## Init Stuff

# %%
import logging
from rich.logging import RichHandler

format_msg = "%(message)s"

level = logging.INFO
tracebacks = False

logging.basicConfig(
    level=level,
    format=format_msg,
    datefmt="[%X]",
    handlers=[RichHandler(rich_tracebacks=tracebacks)],

)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
from epicsarchiver import ArchiverAppliance

# %%
from epicsarchiver.common import ArchDbrType

# %%
archiver_linac_tn = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %% [markdown]
# ## Changes

# %% [markdown]
# ### [AS-227](https://jira.ess.eu/browse/AS-227)

# %%
as_227_pv = "Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat"

# %%
archiver_linac_tn.get_pv_details(as_227_pv)
# Out:
# [{'name': 'PV Name',
#   'value': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#   'source': 'mgmt'},
#  {'name': 'Instance archiving PV',
#   'value': 'archiver-linac-15',
#   'source': 'mgmt'},
#  {'name': 'Archival params creation time:',
#   'value': 'Sep/24/2024 16:26:38 +02:00',
#   'source': 'mgmt'},
#  {'name': 'Archival params modification time:',
#   'value': 'Sep/24/2024 16:26:38 +02:00',
#   'source': 'mgmt'},
#  {'name': 'Archiver DBR type (from typeinfo):',
#   'value': 'DBR_SCALAR_ENUM',
#   'source': 'mgmt'},
#  {'name': 'Is this a scalar:', 'value': 'Yes', 'source': 'mgmt'},
#  {'name': 'Number of elements:', 'value': '1', 'source': 'mgmt'},
#  {'name': 'Precision:', 'value': '0.0', 'source': 'mgmt'},
#  {'name': 'Units:', 'value': '', 'source': 'mgmt'},
#  {'name': 'Is this PV paused:', 'value': 'No', 'source': 'mgmt'},
#  {'name': 'Sampling method:', 'value': 'MONITOR', 'source': 'mgmt'},
#  {'name': 'Sampling period:', 'value': '0.07', 'source': 'mgmt'},
# ...

# %%
archiver_linac_tn.pause_pv(as_227_pv)
# Out:
# {'engine_desc': 'Successfully paused the archiving of PV Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#  'engine_pvName': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#  'engine_status': 'ok',
#  'etl_status': 'ok',
#  'etl_desc': 'Successfully removed PV Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat from the cluster',
#  'etl_pvName': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#  'status': 'ok'}

# %%
archiver_linac_tn.change_type(as_227_pv, ArchDbrType.DBR_SCALAR_DOUBLE)
# Out:
# [15:08:32] INFO     Change type of pv Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat to      ]8;id=523000;file:///Users/skybrewer/git/skybrewer/mgmt_operations/.venv/lib/python3.13/site-packages/epicsarchiver/mgmt/archiver_mgmt_operations.py\archiver_mgmt_operations.py]8;;\:]8;id=291958;file:///Users/skybrewer/git/skybrewer/mgmt_operations/.venv/lib/python3.13/site-packages/epicsarchiver/mgmt/archiver_mgmt_operations.py#294\294]8;;\
#                     ArchDbrType.DBR_SCALAR_DOUBLE

# %%
archiver_linac_tn.resume_pv(as_227_pv)
# Out:
# {'engine_desc': 'Successfully resumed the archiving of PV Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#  'engine_pvName': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#  'engine_status': 'ok',
#  'status': 'ok'}

# %%
archiver_linac_tn.get_pv_status(as_227_pv)
# Out:
# [{'lastRotateLogs': 'Never',
#   'appliance': 'archiver-linac-15',
#   'pvName': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#   'pvNameOnly': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#   'connectionState': 'true',
#   'lastEvent': 'Dec/10/2024 15:10:07 +01:00',
#   'samplingPeriod': '0.07',
#   'isMonitored': 'true',
#   'connectionLastRestablished': 'Never',
#   'connectionFirstEstablished': 'Dec/10/2024 15:10:03 +01:00',
#   'connectionLossRegainCount': '0',
#   'status': 'Being archived'}]

# %%
archiver_linac_tn.get_pv_details(as_227_pv)
# Out:
# [{'name': 'PV Name',
#   'value': 'Tgt-THHeFS:Ctrl-PLC-001:CMS_Heartbeat',
#   'source': 'mgmt'},
#  {'name': 'Instance archiving PV',
#   'value': 'archiver-linac-15',
#   'source': 'mgmt'},
#  {'name': 'Archival params creation time:',
#   'value': 'Sep/24/2024 16:26:38 +02:00',
#   'source': 'mgmt'},
#  {'name': 'Archival params modification time:',
#   'value': 'Dec/10/2024 15:10:03 +01:00',
#   'source': 'mgmt'},
#  {'name': 'Archiver DBR type (from typeinfo):',
#   'value': 'DBR_SCALAR_DOUBLE',
#   'source': 'mgmt'},
#  {'name': 'Is this a scalar:', 'value': 'Yes', 'source': 'mgmt'},
#  {'name': 'Number of elements:', 'value': '1', 'source': 'mgmt'},
#  {'name': 'Precision:', 'value': '0.0', 'source': 'mgmt'},
#  {'name': 'Units:', 'value': '', 'source': 'mgmt'},
#  {'name': 'Is this PV paused:', 'value': 'No', 'source': 'mgmt'},
#  {'name': 'Sampling method:', 'value': 'MONITOR', 'source': 'mgmt'},
#  {'name': 'Sampling period:', 'value': '0.07', 'source': 'mgmt'},
# ...
