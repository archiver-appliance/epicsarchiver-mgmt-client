# %%
import logging

logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    filename="logs/mgmt_operations.as_259.log",
    encoding="utf-8",
)

LOG: logging.Logger = logging.getLogger(__name__)

# %%
pvs = [

"DTL-010:RFS-FIM-101:FirstIlckMsg",
"DTL-020:RFS-FIM-101:FirstIlckMsg",
"DTL-030:RFS-FIM-101:FirstIlckMsg",
"DTL-040:RFS-FIM-101:FirstIlckMsg",
"DTL-050:RFS-FIM-101:FirstIlckMsg",
"RFQ-010:RFS-FIM-101:FirstIlckMsg",
]

# %%
from epicsarchiver import ArchiverAppliance
archiver_linac = ArchiverAppliance("archiver-linac-04.tn.esss.lu.se")

# %%
for pv in pvs:
    archiver_linac.archive_pv(f"pva://{pv}")
